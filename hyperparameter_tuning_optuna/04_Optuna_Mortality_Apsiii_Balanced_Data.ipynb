# %%
from pathlib import Path
import pandas as pd
import numpy as np
import json
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('../src') 

from data_pipeline.extractor import execute_query
from gams.logistic_gam import train_logistic_gam_model
from gams.ebm_gam import train_ebm_model
from ml_models.random_forest import train_random_forest_model
from ml_models.xgb_model import train_xgboost_model

import optuna
from pygam import s, l, te
from sklearn.metrics import roc_auc_score

# %%
query = """
SELECT s.*, a.hospital_expire_flag as mortality
FROM apsiii s
LEFT JOIN admissions a
ON s.subject_id = a.subject_id
AND s.hadm_id = a.hadm_id;
"""

df = execute_query(query)

# Exclude specific columns
df_filtered = df.drop(columns=['subject_id', 'hadm_id', 'icustay_id', 'apsiii', 'apsiii_prob'])

# Replace NaNs with 0
df_filtered = df_filtered.fillna(0)

# Separate majority and minority classes
df_majority = df_filtered[df_filtered.mortality == 0]
df_minority = df_filtered[df_filtered.mortality == 1]

# Oversample minority class to twice its size
df_minority_oversampled = resample(df_minority,
                                   replace=True,     # sample with replacement
                                   n_samples=2*len(df_minority),  # double the minority class size
                                   random_state=42)  # reproducible results

# Downsample majority class to match the original minority class size
df_majority_downsampled = resample(df_majority, 
                                   replace=False,    # sample without replacement
                                   n_samples=len(df_minority_oversampled),  # to match original minority class size
                                   random_state=42)  # reproducible results

# Combine downsampled majority class with oversampled minority class
df_balanced = pd.concat([df_majority_downsampled, df_minority_oversampled])

# Separate features and target variable
y_balanced = df_balanced['mortality']
X_balanced = df_balanced.drop(columns=['mortality'])

# Print class distribution 
print("Class distribution:")
print(y_balanced.value_counts())
# Out:
# Class distribution:
# mortality
# 0    13218
# 1    13218
# Name: count, dtype: int64

# %% [markdown]
# ## LogisticGam Optuna Optimization

# %%
# Define the objective function for Optuna hyperparameter tuning
def objective_gam(trial: optuna.Trial):
    try:
        # Suggest using 'auto' or custom term setup
        terms_option = trial.suggest_categorical("terms_option", ['auto', 'custom'])

        if terms_option == 'auto':
            terms = 'auto'
        else:
            # Predefined set of terms focusing on 15 continuous features
            predefined_terms = [
                # Spline terms for features 0-14
                s(0, n_splines=10, spline_order=3),   # Spline term for feature 0
                s(1, n_splines=15, spline_order=3),   # Spline term for feature 1
                s(2, n_splines=20, spline_order=3),   # Spline term for feature 2
                s(3, n_splines=12, spline_order=3),   # Spline term for feature 3
                s(4, n_splines=18, spline_order=3),   # Spline term for feature 4
                s(5, n_splines=10, spline_order=3),   # Spline term for feature 5
                s(6, n_splines=14, spline_order=3),   # Spline term for feature 6
                s(7, n_splines=16, spline_order=3),   # Spline term for feature 7
                s(8, n_splines=12, spline_order=3),   # Spline term for feature 8
                s(9, n_splines=10, spline_order=3),   # Spline term for feature 9
                s(10, n_splines=15, spline_order=3),  # Spline term for feature 10
                s(11, n_splines=10, spline_order=3),  # Spline term for feature 11
                s(12, n_splines=18, spline_order=3),  # Spline term for feature 12
                s(13, n_splines=12, spline_order=3),  # Spline term for feature 13
                s(14, n_splines=20, spline_order=3),  # Spline term for feature 14
                s(15, n_splines=18, spline_order=3),  # Spline term for feature 14


                # Linear terms for features 0-14
                l(0), l(1), l(2), l(3), l(4), l(5), l(6), l(7), l(8), l(9), 
                l(10), l(11), l(12), l(13), l(14), l(15),

                # Interaction terms between pairs of features
                te(s(0), s(1)),  # Interaction between spline terms of features 0 and 1
                te(s(2), s(3)),  # Interaction between spline terms of features 2 and 3
                te(s(4), s(5)),  # Interaction between spline terms of features 4 and 5
                te(l(6), l(7)),  # Interaction between linear terms of features 6 and 7
                te(l(8), l(9)),  # Interaction between linear terms of features 8 and 9
                te(s(10), l(11)), # Interaction between spline term of feature 10 and linear term of feature 11
                te(s(12), s(13)), # Interaction between spline terms of features 12 and 13
                te(l(13), l(14)),  # Interaction between linear terms of features 13 and 14
                te(l(14), l(15))  # Interaction between linear terms of features 13 and 14

            ]
            
            # Let Optuna select one term from the predefined set
            selected_term_index = trial.suggest_int("selected_term", 0, len(predefined_terms) - 1)
            terms = predefined_terms[selected_term_index]

        # Hyperparameters for the LogisticGAM
        max_iter = trial.suggest_int("max_iter", 50, 500)
        tol = trial.suggest_loguniform("tol", 1e-5, 1e-1)
        fit_intercept = trial.suggest_categorical("fit_intercept", [True, False])

        # Split the data into training and validation sets
        x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(
            X_balanced, y_balanced, test_size=0.2, random_state=42, stratify=y_balanced
        )

        # Initialize StandardScaler
        scaler = StandardScaler()

        # Fit the scaler on the training data and transform both the training and validation sets
        x_train_split = scaler.fit_transform(x_train_split)
        x_valid_split = scaler.transform(x_valid_split)

        # Train the model with the sampled hyperparameters
        _, results = train_logistic_gam_model(
            X_train=x_train_split,
            y_train=y_train_split,
            X_test=x_valid_split,
            terms=terms,
            max_iter=max_iter,
            tol=tol,
            fit_intercept=fit_intercept,
            verbose=False,
            include_summary = False,
        )

        # Calculate the ROC-AUC score on validation data
        roc_auc = roc_auc_score(y_valid_split, results['y_pred_prob'])

        # Maximize ROC-AUC
        return roc_auc

    except Exception as e:
        # Print the error for debugging purposes (optional)
        print(f"Trial failed with error: {e}")

        # Return 0.0 ROC-AUC to indicate failure
        return 0.0  # Low ROC-AUC to signal failure

# %%
# Create an Optuna study with SQLite storage and TPE pruner
study_name = "Optuna_hyperparameter_optimization"
storage_name = "sqlite:///{}.db".format(study_name)

study_gam = optuna.create_study(
    study_name="Case 13: LogisticGam_APSIII_Balanced_Data",
    direction="maximize",  # Maximize ROC-AUC
    storage=storage_name,
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5),
)

# Perform a trial with default values first
default_params = {
    'terms_option': 'auto',
    'max_iter': 100,
    'tol': 0.0001,
    'fit_intercept': True
}
study_gam.enqueue_trial(default_params)

# Define the number of trials (hyperparameter combinations) to search
num_trials = 100

# Perform hyperparameter optimization
study_gam.optimize(objective_gam, n_trials=num_trials, n_jobs=1)
# Out:
# [I 2024-10-22 05:04:07,181] A new study created in RDB with name: Case 13: LogisticGam_APSIII_Balanced_Data
# [I 2024-10-22 05:04:13,422] Trial 0 finished with value: 0.8389464285305582 and parameters: {'terms_option': 'auto', 'max_iter': 100, 'tol': 0.0001, 'fit_intercept': True}. Best is trial 0 with value: 0.8389464285305582.
 'fit_intercept': False}. Best is trial 8 with value: 0.8389574431075641.
# [I 2024-10-22 05:15:20,939] Trial 99 finished with value: 0.8389465715770128 and parameters: {'terms_option': 'auto', 'max_iter': 498, 'tol': 0.038161782792940954, 'fit_intercept': False}. Best is trial 8 with value: 0.8389574431075641.

# %%
# Print the best hyperparameters and best ROC-AUC score
print("Best hyperparameters:", study_gam.best_params)
print("Best ROC-AUC score:", study_gam.best_value)
# Out:
# Best hyperparameters: {'terms_option': 'auto', 'max_iter': 368, 'tol': 0.069513604993303, 'fit_intercept': False}
# Best ROC-AUC score: 0.8389574431075641

# %%
# Save the best configurations to a JSON file
config_file_path = Path("logisticgam_apsiii_balanced_data_best_configs.json")

# Load the saved configuration (if it exists)
if config_file_path.exists():
    with open(config_file_path, "r") as config_file:
        saved_configs = json.load(config_file)

    # Compare the new best value with the saved one
    if study_gam.best_value > saved_configs["best_value"]:
        print("New best value found. Replacing saved configuration.")
        saved_configs["best_params"] = study_gam.best_params
        saved_configs["best_value"] = study_gam.best_value

        # Update the saved configuration file
        with open(config_file_path, "w") as config_file:
            json.dump(saved_configs, config_file)
else:
    # If no saved configuration exists, create a new one
    saved_configs = {
        "best_params": study_gam.best_params,
        "best_value": study_gam.best_value
    }

    with open(config_file_path, "w") as config_file:
        json.dump(saved_configs, config_file)

# %% [markdown]
# ## EBM Optuna Optimization

# %%
# Define the objective function for Optuna hyperparameter tuning
def objective_ebm(trial: optuna.Trial):
    try:
        # Split the data into training and validation sets
        x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(
            X_balanced, y_balanced, test_size=0.2, random_state=42, stratify=y_balanced
        )

        # Initialize StandardScaler
        scaler = StandardScaler()

        # Fit the scaler on the training data and transform both the training and validation sets
        x_train_split = scaler.fit_transform(x_train_split)
        x_valid_split = scaler.transform(x_valid_split)

        # Suggest hyperparameters for EBM
        max_bins = trial.suggest_int('max_bins', 64, 1024)
        max_interaction_bins = trial.suggest_int('max_interaction_bins', 16, 64)
        interactions = trial.suggest_float('interactions', 0.0, 1.0)
        outer_bags = trial.suggest_int('outer_bags', 1, 20)
        inner_bags = trial.suggest_int('inner_bags', 0, 10)
        learning_rate = trial.suggest_float('learning_rate', 0.001, 0.1)
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 100)
        max_leaves = trial.suggest_int('max_leaves', 1, 10)
        max_rounds = trial.suggest_int('max_rounds', 5000, 25000)
        early_stopping_rounds = trial.suggest_int('early_stopping_rounds', 10, 100)
        smoothing_rounds = trial.suggest_int('smoothing_rounds', 50, 500)
        greedy_ratio = trial.suggest_float('greedy_ratio', 0.0, 3.0)

        # Train the model with the sampled hyperparameters
        _, results_ebm = train_ebm_model(
            X_train=x_train_split,
            y_train=y_train_split,
            X_test=x_valid_split,
            max_bins=max_bins,
            max_interaction_bins=max_interaction_bins,
            interactions=interactions,
            outer_bags=outer_bags,
            inner_bags=inner_bags,
            learning_rate=learning_rate,
            min_samples_leaf=min_samples_leaf,
            max_leaves=max_leaves,
            max_rounds=max_rounds,
            early_stopping_rounds=early_stopping_rounds,
            smoothing_rounds=smoothing_rounds,
            greedy_ratio=greedy_ratio,
            random_state=42,  # Fixed random state for reproducibility
        )

        # Calculate the ROC-AUC score on validation data
        roc_auc = roc_auc_score(y_valid_split, results_ebm['y_pred_prob'])

        # Maximize ROC-AUC
        return roc_auc

    except Exception as e:
        # Print the error for debugging purposes (optional)
        print(f"Trial failed with error: {e}")
        
        # Return 0.0 ROC-AUC to indicate failure
        return 0.0

# %%
# Create an Optuna study with SQLite storage and TPE pruner
study_name = "Optuna_hyperparameter_optimization"
storage_name = "sqlite:///{}.db".format(study_name)

study_ebm = optuna.create_study(
    study_name="Case 14: EBM_APSIII_Balanced_Data",
    direction="maximize",  # Maximize ROC-AUC
    storage=storage_name,
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5),  
)

# Perform a trial with default values first
default_params = {
    'max_bins': 1024,
    'max_interaction_bins': 32,
    'interactions': 0.9,
    'outer_bags': 14,
    'inner_bags': 0,
    'learning_rate': 0.01,
    'min_samples_leaf': 2,
    'max_leaves': 3,
    'max_rounds': 25000,
    'early_stopping_rounds': 50,
    'smoothing_rounds': 200,
    'greedy_ratio': 1.5
}
study_ebm.enqueue_trial(default_params)

# Define the number of trials (hyperparameter combinations) to search
num_trials = 100

# Perform hyperparameter optimization
study_ebm.optimize(objective_ebm, n_trials=num_trials, n_jobs=1)
# Out:
# [I 2024-10-22 05:15:21,140] A new study created in RDB with name: Case 14: EBM_APSIII_Balanced_Data
# [I 2024-10-22 05:15:43,069] Trial 0 finished with value: 0.8534913920365467 and parameters: {'max_bins': 1024, 'max_interaction_bins': 32, 'interactions': 0.9, 'outer_bags': 14, 'inner_bags': 0, 'learning_rate': 0.01, 'min_samples_leaf': 2, 'max_leaves': 3, 'max_rounds': 25000, 'early_stopping_rounds': 50, 'smoothing_rounds': 200, 'greedy_ratio': 1.5}. Best is trial 0 with value: 0.8534913920365467.
# [I 2024-10-22 05:15:44,464] Trial 1 finished with value: 0.5 and parameters: {'max_bins': 826, 'max_interaction_bins': 22, 'interactions': 0.001040149710192395, 'outer_bags': 6, 'inner_bags': 7, 'learning_rate': 0.030477301366052097, 'min_samples_leaf': 45, 'max_leaves': 1, 'max_rounds': 15471, 'early_stopping_rounds': 28, 'smoothing_rounds': 70, 'greedy_ratio': 0.5213660522894998}. Best is trial 0 with value: 0.8534913920365467.
# [I 2024-10-22 05:15:46,575] Trial 2 finished with value: 0.8498788968715169 and parameters: {'max_bins': 324, 'max_interaction_bins': 58, 'interactions': 0.3102890002447506, 'outer_bags': 5, 'inner_bags': 9, 'learning_rate': 0.06659835287331578, 'min_samples_leaf': 82, 'max_leaves': 5, 'max_rounds': 21468, 'early_stopping_rounds': 19, 'smoothing_rounds': 85, 'greedy_ratio': 2.3282370891800808}. Best is trial 0 with value: 0.8534913920365467.
# [I 2024-10-22 05:15:59,557] Trial 3 finished with value: 0.8450178922505442 and parameters: {'max_bins': 398, 'max_interaction_bins': 18, 'interactions': 0.081083330199474, 'outer_bags': 7, 'inner_bags': 3, 'learning_rate': 0.00397705235182488, 'min_samples_leaf': 11, 'max_leaves': 10, 'max_rounds': 5462, 'early_stopping_rounds': 90, 'smoothing_rounds': 252, 'greedy_ratio': 1.6943254144892341}. Best is trial 0 with value: 0.8534913920365467.
# [I 2024-10-22 05:16:16,029] Trial 4 finished with value: 0.8542528283145008 and parameters: {'max_bins': 787, 'max_interaction_bins': 54, 'interactions': 0.9786267112607553, 'outer_bags': 6, 'inner_bags': 6, 'learning_rate': 0.02536034306363195, 'min_samples_leaf': 95, 'max_leaves': 3, 'max_rounds': 19395, 'early_stopping_rounds': 55, 'smoothing_rounds': 269, 'greedy_ratio': 1.802798547996775}. Best is trial 4 with value: 0.8542528283145008.
# [I 2024-10-22 05:16:18,985] Trial 5 finished with value: 0.8503558137512274 and parameters: {'max_bins': 410, 'max_interaction_bins': 50, 'interactions': 0.4760027445491166, 'outer_bags': 15, 'inner_bags': 4, 'learning_rate': 0.09191436389619011, 'min_samples_leaf': 99, 'max_leaves': 6, 'max_rounds': 12576, 'early_stopping_rounds': 18, 'smoothing_rounds': 177, 'greedy_ratio': 1.706507811107358}. Best is trial 4 with value: 0.8542528283145008.
# [I 2024-10-22 05:17:17,417] Trial 6 finished with value: 0.8462942957651384 and parameters: {'max_bins': 553, 'max_interaction_bins': 37, 'interactions': 0.143147298709829, 'outer_bags': 19, 'inner_bags': 5, 'learning_rate': 0.012090851791900954, 'min_samples_leaf': 59, 'max_leaves': 2, 'max_rounds': 15618, 'early_stopping_rounds': 57, 'smoothing_rounds': 461, 'greedy_ratio': 2.0176848221350925}. Best is trial 4 with value: 0.8542528283145008.
# [I 2024-10-22 05:17:27,343] Trial 7 finished with value: 0.8503638243526862 and parameters: {'max_bins': 656, 'max_interaction_bins': 21, 'interactions': 0.5259562779691077, 'outer_bags': 20, 'inner_bags': 8, 'learning_rate': 0.046333975486979845, 'min_samples_leaf': 34, 'max_leaves': 4, 'max_rounds': 14689, 'early_stopping_rounds': 49, 'smoothing_rounds': 84, 'greedy_ratio': 1.4840400366733526}. Best is trial 4 with value: 0.8542528283145008.
# [I 2024-10-22 05:17:32,545] Trial 8 finished with value: 0.8442165460117504 and parameters: {'max_bins': 896, 'max_interaction_bins': 21, 'interactions': 0.04813816024353512, 'outer_bags': 10, 'inner_bags': 6, 'learning_rate': 0.047796765020821065, 'min_samples_leaf': 63, 'max_leaves': 5, 'max_rounds': 19997, 'early_stopping_rounds': 35, 'smoothing_rounds': 432, 'greedy_ratio': 2.046747671182562}. Best is trial 4 with value: 0.8542528283145008.
# [I 2024-10-22 05:17:35,452] Trial 9 finished with value: 0.8509358671247205 and parameters: {'max_bins': 942, 'max_interaction_bins': 46, 'interactions': 0.4787002140364709, 'outer_bags': 5, 'inner_bags': 3, 'learning_rate': 0.03276385665474293, 'min_samples_leaf': 39, 'max_leaves': 10, 'max_rounds': 13654, 'early_stopping_rounds': 65, 'smoothing_rounds': 443, 'greedy_ratio': 2.445965678642971}. Best is trial 4 with value: 0.8542528283145008.
# [I 2024-10-22 05:17:38,698] Trial 10 finished with value: 0.8536629047356387 and parameters: {'max_bins': 91, 'max_interaction_bins': 63, 'interactions': 0.9660788470629026, 'outer_bags': 1, 'inner_bags': 10, 'learning_rate': 0.0794084893877265, 'min_samples_leaf': 98, 'max_leaves': 7, 'max_rounds': 8857, 'early_stopping_rounds': 82, 'smoothing_rounds': 333, 'greedy_ratio': 2.928176040519282}. Best is trial 4 with value: 0.8542528283145008.
# [I 2024-10-22 05:17:42,113] Trial 11 finished with value: 0.853725702129218 and parameters: {'max_bins': 64, 'max_interaction_bins': 61, 'interactions': 0.9899749536763054, 'outer_bags': 1, 'inner_bags': 10, 'learning_rate': 0.07720461418536056, 'min_samples_leaf': 99, 'max_leaves': 7, 'max_rounds': 7928, 'early_stopping_rounds': 82, 'smoothing_rounds': 331, 'greedy_ratio': 2.985629138686912}. Best is trial 4 with value: 0.8542528283145008.
# [I 2024-10-22 05:17:45,178] Trial 12 finished with value: 0.8517496584050663 and parameters: {'max_bins': 115, 'max_interaction_bins': 54, 'interactions': 0.7961128359351934, 'outer_bags': 1, 'inner_bags': 10, 'learning_rate': 0.06395440484727488, 'min_samples_leaf': 76, 'max_leaves': 8, 'max_rounds': 19636, 'early_stopping_rounds': 74, 'smoothing_rounds': 351, 'greedy_ratio': 0.645933727128954}. Best is trial 4 with value: 0.8542528283145008.
# [I 2024-10-22 05:17:46,377] Trial 13 finished with value: 0.8517209060676872 and parameters: {'max_bins': 729, 'max_interaction_bins': 64, 'interactions': 0.7053630748153503, 'outer_bags': 3, 'inner_bags': 1, 'learning_rate': 0.09795071944171588, 'min_samples_leaf': 84, 'max_leaves': 8, 'max_rounds': 9628, 'early_stopping_rounds': 92, 'smoothing_rounds': 335, 'greedy_ratio': 2.9739935606198973}. Best is trial 4 with value: 0.8542528283145008.
# [I 2024-10-22 05:17:56,800] Trial 14 finished with value: 0.8514371019017167 and parameters: {'max_bins': 220, 'max_interaction_bins': 45, 'interactions': 0.7212667005362875, 'outer_bags': 10, 'inner_bags': 7, 'learning_rate': 0.026456998857618888, 'min_samples_leaf': 100, 'max_leaves': 3, 'max_rounds': 5355, 'early_stopping_rounds': 99, 'smoothing_rounds': 274, 'greedy_ratio': 0.9796438860033904}. Best is trial 4 with value: 0.8542528283145008.
# [I 2024-10-22 05:18:05,649] Trial 15 finished with value: 0.8559161724888481 and parameters: {'max_bins': 580, 'max_interaction_bins': 58, 'interactions': 0.9965860523844231, 'outer_bags': 8, 'inner_bags': 8, 'learning_rate': 0.06799157687626578, 'min_samples_leaf': 75, 'max_leaves': 7, 'max_rounds': 17941, 'early_stopping_rounds': 73, 'smoothing_rounds': 371, 'greedy_ratio': 1.0766836867354197}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:18:12,311] Trial 16 finished with value: 0.8544437953314215 and parameters: {'max_bins': 616, 'max_interaction_bins': 53, 'interactions': 0.8325032338483181, 'outer_bags': 9, 'inner_bags': 8, 'learning_rate': 0.056467243276748985, 'min_samples_leaf': 71, 'max_leaves': 4, 'max_rounds': 17763, 'early_stopping_rounds': 65, 'smoothing_rounds': 389, 'greedy_ratio': 0.9515108252268725}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:18:21,416] Trial 17 finished with value: 0.8526811769175664 and parameters: {'max_bins': 591, 'max_interaction_bins': 41, 'interactions': 0.8035485679666547, 'outer_bags': 12, 'inner_bags': 8, 'learning_rate': 0.05947389235488633, 'min_samples_leaf': 66, 'max_leaves': 6, 'max_rounds': 17279, 'early_stopping_rounds': 68, 'smoothing_rounds': 403, 'greedy_ratio': 0.0030088417487053043}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:18:34,250] Trial 18 finished with value: 0.8527047795825791 and parameters: {'max_bins': 468, 'max_interaction_bins': 55, 'interactions': 0.6206776302165242, 'outer_bags': 8, 'inner_bags': 8, 'learning_rate': 0.07389955796036754, 'min_samples_leaf': 73, 'max_leaves': 8, 'max_rounds': 22265, 'early_stopping_rounds': 40, 'smoothing_rounds': 499, 'greedy_ratio': 1.1088698998030455}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:18:48,679] Trial 19 finished with value: 0.8540784546863162 and parameters: {'max_bins': 707, 'max_interaction_bins': 49, 'interactions': 0.8574751124986737, 'outer_bags': 12, 'inner_bags': 6, 'learning_rate': 0.04150234514124815, 'min_samples_leaf': 51, 'max_leaves': 4, 'max_rounds': 17140, 'early_stopping_rounds': 75, 'smoothing_rounds': 380, 'greedy_ratio': 1.118249784246316}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:18:53,204] Trial 20 finished with value: 0.5 and parameters: {'max_bins': 507, 'max_interaction_bins': 33, 'interactions': 0.3451820906603263, 'outer_bags': 17, 'inner_bags': 9, 'learning_rate': 0.05487590735439955, 'min_samples_leaf': 87, 'max_leaves': 1, 'max_rounds': 11901, 'early_stopping_rounds': 61, 'smoothing_rounds': 388, 'greedy_ratio': 0.45621505950871155}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:18:59,205] Trial 21 finished with value: 0.853707106090117 and parameters: {'max_bins': 774, 'max_interaction_bins': 54, 'interactions': 0.9160262677600947, 'outer_bags': 8, 'inner_bags': 6, 'learning_rate': 0.08596171979016758, 'min_samples_leaf': 90, 'max_leaves': 3, 'max_rounds': 18211, 'early_stopping_rounds': 49, 'smoothing_rounds': 231, 'greedy_ratio': 0.7684045153172654}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:19:11,583] Trial 22 finished with value: 0.855214529628926 and parameters: {'max_bins': 632, 'max_interaction_bins': 59, 'interactions': 0.9778854612466227, 'outer_bags': 9, 'inner_bags': 7, 'learning_rate': 0.020135619598374316, 'min_samples_leaf': 74, 'max_leaves': 4, 'max_rounds': 22643, 'early_stopping_rounds': 70, 'smoothing_rounds': 299, 'greedy_ratio': 1.2520515208901102}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:19:20,268] Trial 23 finished with value: 0.8542601236836864 and parameters: {'max_bins': 613, 'max_interaction_bins': 58, 'interactions': 0.8253934432806164, 'outer_bags': 9, 'inner_bags': 7, 'learning_rate': 0.03876938291996399, 'min_samples_leaf': 72, 'max_leaves': 4, 'max_rounds': 24460, 'early_stopping_rounds': 71, 'smoothing_rounds': 309, 'greedy_ratio': 1.3151927584378142}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:19:30,094] Trial 24 finished with value: 0.8528193597927314 and parameters: {'max_bins': 677, 'max_interaction_bins': 59, 'interactions': 0.7329497701991134, 'outer_bags': 12, 'inner_bags': 8, 'learning_rate': 0.06950033356267739, 'min_samples_leaf': 57, 'max_leaves': 5, 'max_rounds': 22801, 'early_stopping_rounds': 80, 'smoothing_rounds': 368, 'greedy_ratio': 0.8412778834594425}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:19:37,110] Trial 25 finished with value: 0.8543662641530161 and parameters: {'max_bins': 477, 'max_interaction_bins': 50, 'interactions': 0.9024013219203181, 'outer_bags': 11, 'inner_bags': 9, 'learning_rate': 0.05598018218709286, 'min_samples_leaf': 77, 'max_leaves': 7, 'max_rounds': 20930, 'early_stopping_rounds': 63, 'smoothing_rounds': 304, 'greedy_ratio': 0.21232515598891577}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:19:48,836] Trial 26 finished with value: 0.8531490818706355 and parameters: {'max_bins': 600, 'max_interaction_bins': 43, 'interactions': 0.6322209720289326, 'outer_bags': 14, 'inner_bags': 5, 'learning_rate': 0.016966890090814767, 'min_samples_leaf': 65, 'max_leaves': 9, 'max_rounds': 23205, 'early_stopping_rounds': 89, 'smoothing_rounds': 409, 'greedy_ratio': 1.30118072567383}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:19:59,887] Trial 27 finished with value: 0.8544795569450772 and parameters: {'max_bins': 330, 'max_interaction_bins': 57, 'interactions': 0.9075296424928875, 'outer_bags': 9, 'inner_bags': 7, 'learning_rate': 0.05179682503947375, 'min_samples_leaf': 52, 'max_leaves': 6, 'max_rounds': 17894, 'early_stopping_rounds': 78, 'smoothing_rounds': 486, 'greedy_ratio': 1.2443791119253038}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:20:08,467] Trial 28 finished with value: 0.8547882511941518 and parameters: {'max_bins': 306, 'max_interaction_bins': 60, 'interactions': 0.9910114047023411, 'outer_bags': 4, 'inner_bags': 5, 'learning_rate': 0.040225233972996835, 'min_samples_leaf': 34, 'max_leaves': 6, 'max_rounds': 16187, 'early_stopping_rounds': 79, 'smoothing_rounds': 493, 'greedy_ratio': 1.2754099988907661}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:20:13,409] Trial 29 finished with value: 0.8546732418446354 and parameters: {'max_bins': 230, 'max_interaction_bins': 61, 'interactions': 0.9387541417929185, 'outer_bags': 3, 'inner_bags': 4, 'learning_rate': 0.020996658345610156, 'min_samples_leaf': 19, 'max_leaves': 7, 'max_rounds': 24455, 'early_stopping_rounds': 99, 'smoothing_rounds': 193, 'greedy_ratio': 1.3775085670382883}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:20:15,388] Trial 30 finished with value: 0.8532557945257837 and parameters: {'max_bins': 276, 'max_interaction_bins': 26, 'interactions': 0.9920981104637357, 'outer_bags': 3, 'inner_bags': 1, 'learning_rate': 0.0362078099447294, 'min_samples_leaf': 31, 'max_leaves': 6, 'max_rounds': 11408, 'early_stopping_rounds': 86, 'smoothing_rounds': 119, 'greedy_ratio': 1.576521279645134}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:20:20,749] Trial 31 finished with value: 0.8545635252139403 and parameters: {'max_bins': 187, 'max_interaction_bins': 61, 'interactions': 0.9215034692369761, 'outer_bags': 3, 'inner_bags': 4, 'learning_rate': 0.022101619816827976, 'min_samples_leaf': 19, 'max_leaves': 7, 'max_rounds': 23379, 'early_stopping_rounds': 99, 'smoothing_rounds': 200, 'greedy_ratio': 1.461627456953997}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:20:26,962] Trial 32 finished with value: 0.8534996887309148 and parameters: {'max_bins': 184, 'max_interaction_bins': 62, 'interactions': 0.8590335789225103, 'outer_bags': 4, 'inner_bags': 4, 'learning_rate': 0.015274691124593346, 'min_samples_leaf': 2, 'max_leaves': 9, 'max_rounds': 24982, 'early_stopping_rounds': 93, 'smoothing_rounds': 155, 'greedy_ratio': 1.1208138350234365}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:20:44,341] Trial 33 finished with value: 0.8536380146525344 and parameters: {'max_bins': 311, 'max_interaction_bins': 64, 'interactions': 0.9247870293885789, 'outer_bags': 6, 'inner_bags': 5, 'learning_rate': 0.005889365829667946, 'min_samples_leaf': 19, 'max_leaves': 5, 'max_rounds': 21315, 'early_stopping_rounds': 71, 'smoothing_rounds': 220, 'greedy_ratio': 1.874016555198996}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:20:47,500] Trial 34 finished with value: 0.8529931612350974 and parameters: {'max_bins': 401, 'max_interaction_bins': 59, 'interactions': 0.7627365186504137, 'outer_bags': 4, 'inner_bags': 2, 'learning_rate': 0.030804343129458116, 'min_samples_leaf': 26, 'max_leaves': 7, 'max_rounds': 15864, 'early_stopping_rounds': 85, 'smoothing_rounds': 160, 'greedy_ratio': 1.415012093676828}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:21:30,397] Trial 35 finished with value: 0.8531718262569205 and parameters: {'max_bins': 537, 'max_interaction_bins': 57, 'interactions': 0.997936276609389, 'outer_bags': 7, 'inner_bags': 3, 'learning_rate': 0.0012832496383125731, 'min_samples_leaf': 19, 'max_leaves': 8, 'max_rounds': 20488, 'early_stopping_rounds': 95, 'smoothing_rounds': 296, 'greedy_ratio': 0.4465401082544953}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:21:34,678] Trial 36 finished with value: 0.8548557691207334 and parameters: {'max_bins': 358, 'max_interaction_bins': 51, 'interactions': 0.8699130649378903, 'outer_bags': 5, 'inner_bags': 5, 'learning_rate': 0.020211324350130018, 'min_samples_leaf': 42, 'max_leaves': 6, 'max_rounds': 24024, 'early_stopping_rounds': 78, 'smoothing_rounds': 251, 'greedy_ratio': 1.5817820123337532}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:21:40,589] Trial 37 finished with value: 0.8541315249209812 and parameters: {'max_bins': 428, 'max_interaction_bins': 52, 'interactions': 0.8750848127523685, 'outer_bags': 7, 'inner_bags': 5, 'learning_rate': 0.010615332727860645, 'min_samples_leaf': 42, 'max_leaves': 6, 'max_rounds': 19297, 'early_stopping_rounds': 11, 'smoothing_rounds': 248, 'greedy_ratio': 2.196921618349156}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:21:47,328] Trial 38 finished with value: 0.8476483735045923 and parameters: {'max_bins': 346, 'max_interaction_bins': 48, 'interactions': 0.23408841605213537, 'outer_bags': 5, 'inner_bags': 6, 'learning_rate': 0.028224295972363023, 'min_samples_leaf': 49, 'max_leaves': 5, 'max_rounds': 21677, 'early_stopping_rounds': 57, 'smoothing_rounds': 289, 'greedy_ratio': 1.6084056813254968}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:22:23,685] Trial 39 finished with value: 0.851299920351734 and parameters: {'max_bins': 378, 'max_interaction_bins': 56, 'interactions': 0.6454865626728628, 'outer_bags': 6, 'inner_bags': 7, 'learning_rate': 0.04412079933855552, 'min_samples_leaf': 36, 'max_leaves': 2, 'max_rounds': 14543, 'early_stopping_rounds': 75, 'smoothing_rounds': 468, 'greedy_ratio': 1.8515675865431234}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:22:30,786] Trial 40 finished with value: 0.8512245348701482 and parameters: {'max_bins': 874, 'max_interaction_bins': 51, 'interactions': 0.5580610137166206, 'outer_bags': 7, 'inner_bags': 9, 'learning_rate': 0.021059067483848684, 'min_samples_leaf': 46, 'max_leaves': 5, 'max_rounds': 16401, 'early_stopping_rounds': 53, 'smoothing_rounds': 257, 'greedy_ratio': 0.6445155838292487}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:22:43,053] Trial 41 finished with value: 0.8552804740445069 and parameters: {'max_bins': 267, 'max_interaction_bins': 61, 'interactions': 0.9699316987861101, 'outer_bags': 4, 'inner_bags': 4, 'learning_rate': 0.019335378357128997, 'min_samples_leaf': 28, 'max_leaves': 6, 'max_rounds': 24422, 'early_stopping_rounds': 85, 'smoothing_rounds': 208, 'greedy_ratio': 1.70873828312756}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:22:51,342] Trial 42 finished with value: 0.8542548309648654 and parameters: {'max_bins': 288, 'max_interaction_bins': 59, 'interactions': 0.9669278170503931, 'outer_bags': 5, 'inner_bags': 3, 'learning_rate': 0.00797275615715469, 'min_samples_leaf': 32, 'max_leaves': 6, 'max_rounds': 23698, 'early_stopping_rounds': 86, 'smoothing_rounds': 238, 'greedy_ratio': 1.718885894141223}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:22:58,006] Trial 43 finished with value: 0.8532628038020604 and parameters: {'max_bins': 448, 'max_interaction_bins': 37, 'interactions': 0.9437753114681174, 'outer_bags': 2, 'inner_bags': 5, 'learning_rate': 0.01613089233782123, 'min_samples_leaf': 24, 'max_leaves': 5, 'max_rounds': 22159, 'early_stopping_rounds': 79, 'smoothing_rounds': 215, 'greedy_ratio': 1.2131951145890065}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:06,512] Trial 44 finished with value: 0.854829448573083 and parameters: {'max_bins': 139, 'max_interaction_bins': 60, 'interactions': 0.8603705139303478, 'outer_bags': 4, 'inner_bags': 4, 'learning_rate': 0.033298610388882155, 'min_samples_leaf': 39, 'max_leaves': 6, 'max_rounds': 23832, 'early_stopping_rounds': 69, 'smoothing_rounds': 132, 'greedy_ratio': 1.9745271180934527}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:11,504] Trial 45 finished with value: 0.8521991103654893 and parameters: {'max_bins': 164, 'max_interaction_bins': 64, 'interactions': 0.762086908156437, 'outer_bags': 6, 'inner_bags': 2, 'learning_rate': 0.03554074163847705, 'min_samples_leaf': 56, 'max_leaves': 4, 'max_rounds': 24041, 'early_stopping_rounds': 69, 'smoothing_rounds': 138, 'greedy_ratio': 2.2047893806137084}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:17,707] Trial 46 finished with value: 0.8525223953529355 and parameters: {'max_bins': 146, 'max_interaction_bins': 47, 'interactions': 0.869856876159128, 'outer_bags': 8, 'inner_bags': 3, 'learning_rate': 0.01331641912469031, 'min_samples_leaf': 43, 'max_leaves': 7, 'max_rounds': 22483, 'early_stopping_rounds': 60, 'smoothing_rounds': 58, 'greedy_ratio': 2.4398783382548483}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:27,464] Trial 47 finished with value: 0.8506790987386736 and parameters: {'max_bins': 253, 'max_interaction_bins': 56, 'interactions': 0.4383502701956393, 'outer_bags': 2, 'inner_bags': 4, 'learning_rate': 0.023287624674826223, 'min_samples_leaf': 38, 'max_leaves': 6, 'max_rounds': 23507, 'early_stopping_rounds': 67, 'smoothing_rounds': 118, 'greedy_ratio': 1.9237566588509027}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:29,980] Trial 48 finished with value: 0.8529923029563697 and parameters: {'max_bins': 362, 'max_interaction_bins': 52, 'interactions': 0.8238124203565286, 'outer_bags': 5, 'inner_bags': 6, 'learning_rate': 0.029586480943205845, 'min_samples_leaf': 80, 'max_leaves': 8, 'max_rounds': 20140, 'early_stopping_rounds': 75, 'smoothing_rounds': 175, 'greedy_ratio': 2.0670358091983876}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:34,100] Trial 49 finished with value: 0.8523294256856503 and parameters: {'max_bins': 550, 'max_interaction_bins': 55, 'interactions': 0.6674259988646467, 'outer_bags': 10, 'inner_bags': 2, 'learning_rate': 0.019045760563149657, 'min_samples_leaf': 62, 'max_leaves': 5, 'max_rounds': 24978, 'early_stopping_rounds': 84, 'smoothing_rounds': 99, 'greedy_ratio': 1.6652381730633246}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:37,876] Trial 50 finished with value: 0.8502835752916432 and parameters: {'max_bins': 1011, 'max_interaction_bins': 61, 'interactions': 0.7734197966801993, 'outer_bags': 2, 'inner_bags': 3, 'learning_rate': 0.025126035907666013, 'min_samples_leaf': 28, 'max_leaves': 3, 'max_rounds': 19199, 'early_stopping_rounds': 89, 'smoothing_rounds': 268, 'greedy_ratio': 2.740638697009009}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:41,903] Trial 51 finished with value: 0.8545682457469429 and parameters: {'max_bins': 104, 'max_interaction_bins': 60, 'interactions': 0.9613429833050539, 'outer_bags': 4, 'inner_bags': 5, 'learning_rate': 0.034745327538871225, 'min_samples_leaf': 41, 'max_leaves': 6, 'max_rounds': 14079, 'early_stopping_rounds': 77, 'smoothing_rounds': 432, 'greedy_ratio': 1.5132147853361244}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:45,485] Trial 52 finished with value: 0.8546051517322355 and parameters: {'max_bins': 225, 'max_interaction_bins': 63, 'interactions': 0.8797676461407209, 'outer_bags': 4, 'inner_bags': 4, 'learning_rate': 0.03961738593120222, 'min_samples_leaf': 34, 'max_leaves': 7, 'max_rounds': 13024, 'early_stopping_rounds': 71, 'smoothing_rounds': 323, 'greedy_ratio': 0.9842130927362883}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:49,826] Trial 53 finished with value: 0.8557313564694761 and parameters: {'max_bins': 642, 'max_interaction_bins': 58, 'interactions': 0.9733679203939157, 'outer_bags': 7, 'inner_bags': 6, 'learning_rate': 0.046379311409000236, 'min_samples_leaf': 47, 'max_leaves': 6, 'max_rounds': 21662, 'early_stopping_rounds': 82, 'smoothing_rounds': 349, 'greedy_ratio': 1.7531977527581983}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:53,470] Trial 54 finished with value: 0.8556744239805366 and parameters: {'max_bins': 775, 'max_interaction_bins': 57, 'interactions': 0.9560748163998897, 'outer_bags': 7, 'inner_bags': 6, 'learning_rate': 0.0613252896752588, 'min_samples_leaf': 45, 'max_leaves': 5, 'max_rounds': 21816, 'early_stopping_rounds': 82, 'smoothing_rounds': 353, 'greedy_ratio': 1.769580898684585}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:23:58,877] Trial 55 finished with value: 0.8552910594821489 and parameters: {'max_bins': 767, 'max_interaction_bins': 53, 'interactions': 0.9404118174733812, 'outer_bags': 8, 'inner_bags': 6, 'learning_rate': 0.06349647379017163, 'min_samples_leaf': 47, 'max_leaves': 4, 'max_rounds': 21242, 'early_stopping_rounds': 83, 'smoothing_rounds': 355, 'greedy_ratio': 1.7221754681696342}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:24:04,300] Trial 56 finished with value: 0.8556807180245399 and parameters: {'max_bins': 775, 'max_interaction_bins': 54, 'interactions': 0.95544244867325, 'outer_bags': 8, 'inner_bags': 7, 'learning_rate': 0.07077662796545307, 'min_samples_leaf': 68, 'max_leaves': 4, 'max_rounds': 18688, 'early_stopping_rounds': 82, 'smoothing_rounds': 354, 'greedy_ratio': 1.7645422909558193}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:24:10,596] Trial 57 finished with value: 0.8552066620739218 and parameters: {'max_bins': 797, 'max_interaction_bins': 54, 'interactions': 0.9628450392681928, 'outer_bags': 8, 'inner_bags': 6, 'learning_rate': 0.06218920762140216, 'min_samples_leaf': 69, 'max_leaves': 4, 'max_rounds': 19162, 'early_stopping_rounds': 82, 'smoothing_rounds': 357, 'greedy_ratio': 1.7581670501865352}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:24:19,348] Trial 58 finished with value: 0.8553644423133703 and parameters: {'max_bins': 731, 'max_interaction_bins': 44, 'interactions': 0.9419344858952442, 'outer_bags': 11, 'inner_bags': 8, 'learning_rate': 0.07060440510289352, 'min_samples_leaf': 54, 'max_leaves': 3, 'max_rounds': 18398, 'early_stopping_rounds': 95, 'smoothing_rounds': 412, 'greedy_ratio': 2.1031103055898375}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:24:36,722] Trial 59 finished with value: 0.852845966433291 and parameters: {'max_bins': 744, 'max_interaction_bins': 45, 'interactions': 0.902272388008462, 'outer_bags': 11, 'inner_bags': 8, 'learning_rate': 0.0692160796006089, 'min_samples_leaf': 54, 'max_leaves': 2, 'max_rounds': 18406, 'early_stopping_rounds': 95, 'smoothing_rounds': 404, 'greedy_ratio': 2.12679295336893}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:24:43,463] Trial 60 finished with value: 0.8520172983216645 and parameters: {'max_bins': 674, 'max_interaction_bins': 39, 'interactions': 0.7998541766384735, 'outer_bags': 14, 'inner_bags': 9, 'learning_rate': 0.08279009382504034, 'min_samples_leaf': 48, 'max_leaves': 3, 'max_rounds': 17100, 'early_stopping_rounds': 90, 'smoothing_rounds': 349, 'greedy_ratio': 2.2987116754635366}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:24:47,778] Trial 61 finished with value: 0.8555604159562026 and parameters: {'max_bins': 850, 'max_interaction_bins': 57, 'interactions': 0.9420096646996969, 'outer_bags': 10, 'inner_bags': 6, 'learning_rate': 0.07280163737378231, 'min_samples_leaf': 60, 'max_leaves': 4, 'max_rounds': 20971, 'early_stopping_rounds': 88, 'smoothing_rounds': 372, 'greedy_ratio': 1.764079553367598}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:24:52,944] Trial 62 finished with value: 0.8559050148653875 and parameters: {'max_bins': 819, 'max_interaction_bins': 53, 'interactions': 0.9324588900398474, 'outer_bags': 13, 'inner_bags': 7, 'learning_rate': 0.07465095259437517, 'min_samples_leaf': 61, 'max_leaves': 4, 'max_rounds': 18695, 'early_stopping_rounds': 95, 'smoothing_rounds': 372, 'greedy_ratio': 1.779444560593381}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:24:59,224] Trial 63 finished with value: 0.8534564887016189 and parameters: {'max_bins': 842, 'max_interaction_bins': 16, 'interactions': 0.8317834984483394, 'outer_bags': 13, 'inner_bags': 7, 'learning_rate': 0.07416097639829078, 'min_samples_leaf': 61, 'max_leaves': 3, 'max_rounds': 18574, 'early_stopping_rounds': 95, 'smoothing_rounds': 372, 'greedy_ratio': 1.8200374785197282}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:25:06,975] Trial 64 finished with value: 0.8543741317080203 and parameters: {'max_bins': 829, 'max_interaction_bins': 57, 'interactions': 0.8990716281422982, 'outer_bags': 16, 'inner_bags': 8, 'learning_rate': 0.06764725432960013, 'min_samples_leaf': 58, 'max_leaves': 4, 'max_rounds': 20608, 'early_stopping_rounds': 92, 'smoothing_rounds': 418, 'greedy_ratio': 2.0197326234830113}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:25:19,434] Trial 65 finished with value: 0.8525485728541315 and parameters: {'max_bins': 933, 'max_interaction_bins': 49, 'interactions': 0.9305974119962599, 'outer_bags': 11, 'inner_bags': 7, 'learning_rate': 0.07315335168464163, 'min_samples_leaf': 66, 'max_leaves': 2, 'max_rounds': 19848, 'early_stopping_rounds': 88, 'smoothing_rounds': 392, 'greedy_ratio': 2.3850576833777297}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:25:24,690] Trial 66 finished with value: 0.8550766328466702 and parameters: {'max_bins': 709, 'max_interaction_bins': 28, 'interactions': 0.9964060378107461, 'outer_bags': 13, 'inner_bags': 7, 'learning_rate': 0.09041941612477326, 'min_samples_leaf': 54, 'max_leaves': 3, 'max_rounds': 21821, 'early_stopping_rounds': 96, 'smoothing_rounds': 319, 'greedy_ratio': 1.870728331202254}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:25:29,357] Trial 67 finished with value: 0.8555432503816478 and parameters: {'max_bins': 801, 'max_interaction_bins': 55, 'interactions': 0.9563068030742901, 'outer_bags': 10, 'inner_bags': 6, 'learning_rate': 0.0787459336689241, 'min_samples_leaf': 69, 'max_leaves': 4, 'max_rounds': 16820, 'early_stopping_rounds': 81, 'smoothing_rounds': 443, 'greedy_ratio': 1.937764300669393}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:25:33,584] Trial 68 finished with value: 0.8540612891117616 and parameters: {'max_bins': 882, 'max_interaction_bins': 55, 'interactions': 0.9034743940961738, 'outer_bags': 10, 'inner_bags': 6, 'learning_rate': 0.07984714356591474, 'min_samples_leaf': 69, 'max_leaves': 4, 'max_rounds': 15336, 'early_stopping_rounds': 73, 'smoothing_rounds': 343, 'greedy_ratio': 1.969053110940109}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:25:37,658] Trial 69 finished with value: 0.8441528903394434 and parameters: {'max_bins': 927, 'max_interaction_bins': 58, 'interactions': 0.03552989251249683, 'outer_bags': 9, 'inner_bags': 6, 'learning_rate': 0.05955576169350866, 'min_samples_leaf': 82, 'max_leaves': 5, 'max_rounds': 17328, 'early_stopping_rounds': 81, 'smoothing_rounds': 454, 'greedy_ratio': 1.4788242743270066}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:25:41,080] Trial 70 finished with value: 0.854606439150327 and parameters: {'max_bins': 805, 'max_interaction_bins': 53, 'interactions': 0.8415951472582296, 'outer_bags': 10, 'inner_bags': 7, 'learning_rate': 0.07755988479358925, 'min_samples_leaf': 77, 'max_leaves': 4, 'max_rounds': 16611, 'early_stopping_rounds': 28, 'smoothing_rounds': 371, 'greedy_ratio': 2.5701642201772668}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:25:47,246] Trial 71 finished with value: 0.8556662703326231 and parameters: {'max_bins': 749, 'max_interaction_bins': 56, 'interactions': 0.9511572860987808, 'outer_bags': 12, 'inner_bags': 8, 'learning_rate': 0.07088572766539382, 'min_samples_leaf': 64, 'max_leaves': 4, 'max_rounds': 18856, 'early_stopping_rounds': 92, 'smoothing_rounds': 422, 'greedy_ratio': 2.1398618399377782}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:25:53,536] Trial 72 finished with value: 0.8556263603717834 and parameters: {'max_bins': 856, 'max_interaction_bins': 56, 'interactions': 0.9576699936289963, 'outer_bags': 13, 'inner_bags': 8, 'learning_rate': 0.06585591745472491, 'min_samples_leaf': 60, 'max_leaves': 4, 'max_rounds': 18806, 'early_stopping_rounds': 88, 'smoothing_rounds': 428, 'greedy_ratio': 1.8131280835714927}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:25:58,612] Trial 73 finished with value: 0.8542342322753999 and parameters: {'max_bins': 850, 'max_interaction_bins': 57, 'interactions': 0.891232411056977, 'outer_bags': 13, 'inner_bags': 8, 'learning_rate': 0.05004605200044766, 'min_samples_leaf': 60, 'max_leaves': 5, 'max_rounds': 18767, 'early_stopping_rounds': 87, 'smoothing_rounds': 428, 'greedy_ratio': 1.5762938437367906}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:26:03,504] Trial 74 finished with value: 0.8542476786421345 and parameters: {'max_bins': 644, 'max_interaction_bins': 58, 'interactions': 0.9283219315931412, 'outer_bags': 15, 'inner_bags': 7, 'learning_rate': 0.06689020664596815, 'min_samples_leaf': 63, 'max_leaves': 4, 'max_rounds': 20244, 'early_stopping_rounds': 91, 'smoothing_rounds': 392, 'greedy_ratio': 1.7859903915979225}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:26:09,550] Trial 75 finished with value: 0.8557482359511216 and parameters: {'max_bins': 581, 'max_interaction_bins': 56, 'interactions': 0.9926051683001769, 'outer_bags': 12, 'inner_bags': 9, 'learning_rate': 0.059429873844291485, 'min_samples_leaf': 65, 'max_leaves': 5, 'max_rounds': 6289, 'early_stopping_rounds': 100, 'smoothing_rounds': 381, 'greedy_ratio': 1.6213747131459249}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:26:14,652] Trial 76 finished with value: 0.8557771313349551 and parameters: {'max_bins': 587, 'max_interaction_bins': 50, 'interactions': 0.9981240713217298, 'outer_bags': 14, 'inner_bags': 9, 'learning_rate': 0.058747391687030845, 'min_samples_leaf': 67, 'max_leaves': 5, 'max_rounds': 7317, 'early_stopping_rounds': 97, 'smoothing_rounds': 332, 'greedy_ratio': 1.6639510484552693}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:26:20,293] Trial 77 finished with value: 0.8555478278681959 and parameters: {'max_bins': 587, 'max_interaction_bins': 50, 'interactions': 0.9996521385626832, 'outer_bags': 12, 'inner_bags': 9, 'learning_rate': 0.05950265988247329, 'min_samples_leaf': 75, 'max_leaves': 5, 'max_rounds': 6623, 'early_stopping_rounds': 100, 'smoothing_rounds': 335, 'greedy_ratio': 1.6431148659410606}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:26:26,467] Trial 78 finished with value: 0.8461233552518648 and parameters: {'max_bins': 503, 'max_interaction_bins': 53, 'interactions': 0.11765605425555725, 'outer_bags': 15, 'inner_bags': 10, 'learning_rate': 0.053410756817334516, 'min_samples_leaf': 65, 'max_leaves': 5, 'max_rounds': 6837, 'early_stopping_rounds': 98, 'smoothing_rounds': 319, 'greedy_ratio': 1.428086567137178}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:26:33,474] Trial 79 finished with value: 0.8557935816772368 and parameters: {'max_bins': 690, 'max_interaction_bins': 51, 'interactions': 0.9796955286679055, 'outer_bags': 17, 'inner_bags': 9, 'learning_rate': 0.04883037172003908, 'min_samples_leaf': 72, 'max_leaves': 5, 'max_rounds': 9826, 'early_stopping_rounds': 93, 'smoothing_rounds': 383, 'greedy_ratio': 1.5281015735579244}. Best is trial 15 with value: 0.8559161724888481.
# [I 2024-10-22 05:26:43,351] Trial 80 finished with value: 0.8560246017014518 and parameters: {'max_bins': 573, 'max_interaction_bins': 47, 'interactions': 0.9870541258936102, 'outer_bags': 18, 'inner_bags': 10, 'learning_rate': 0.04400929037719808, 'min_samples_leaf': 72, 'max_leaves': 5, 'max_rounds': 9980, 'early_stopping_rounds': 98, 'smoothing_rounds': 360, 'greedy_ratio': 1.3676687954745075}. Best is trial 80 with value: 0.8560246017014518.
# [I 2024-10-22 05:26:54,602] Trial 81 finished with value: 0.8559937036672534 and parameters: {'max_bins': 576, 'max_interaction_bins': 49, 'interactions': 0.9783209947153294, 'outer_bags': 17, 'inner_bags': 10, 'learning_rate': 0.0472427220002228, 'min_samples_leaf': 88, 'max_leaves': 5, 'max_rounds': 9051, 'early_stopping_rounds': 97, 'smoothing_rounds': 362, 'greedy_ratio': 1.3826749637898152}. Best is trial 80 with value: 0.8560246017014518.
# [I 2024-10-22 05:27:11,953] Trial 82 finished with value: 0.855847653237084 and parameters: {'max_bins': 579, 'max_interaction_bins': 47, 'interactions': 0.9835443194281158, 'outer_bags': 18, 'inner_bags': 10, 'learning_rate': 0.046415402331978106, 'min_samples_leaf': 73, 'max_leaves': 5, 'max_rounds': 9124, 'early_stopping_rounds': 97, 'smoothing_rounds': 383, 'greedy_ratio': 1.3762472810491149}. Best is trial 80 with value: 0.8560246017014518.
# [I 2024-10-22 05:27:29,482] Trial 83 finished with value: 0.8558352081955319 and parameters: {'max_bins': 577, 'max_interaction_bins': 48, 'interactions': 0.979024124202072, 'outer_bags': 18, 'inner_bags': 10, 'learning_rate': 0.045782723678996266, 'min_samples_leaf': 95, 'max_leaves': 5, 'max_rounds': 9915, 'early_stopping_rounds': 97, 'smoothing_rounds': 383, 'greedy_ratio': 1.2015724686715241}. Best is trial 80 with value: 0.8560246017014518.
# [I 2024-10-22 05:27:48,581] Trial 84 finished with value: 0.856105565994768 and parameters: {'max_bins': 581, 'max_interaction_bins': 47, 'interactions': 0.9998168404207781, 'outer_bags': 18, 'inner_bags': 10, 'learning_rate': 0.04367020510396994, 'min_samples_leaf': 96, 'max_leaves': 5, 'max_rounds': 10124, 'early_stopping_rounds': 97, 'smoothing_rounds': 386, 'greedy_ratio': 1.3695083018257845}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:28:01,618] Trial 85 finished with value: 0.855924183090307 and parameters: {'max_bins': 528, 'max_interaction_bins': 42, 'interactions': 0.977880870626101, 'outer_bags': 18, 'inner_bags': 10, 'learning_rate': 0.0425453242540125, 'min_samples_leaf': 95, 'max_leaves': 5, 'max_rounds': 9611, 'early_stopping_rounds': 97, 'smoothing_rounds': 389, 'greedy_ratio': 1.1413642860190152}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:28:20,657] Trial 86 finished with value: 0.8544463701676046 and parameters: {'max_bins': 517, 'max_interaction_bins': 42, 'interactions': 0.9157766805236607, 'outer_bags': 19, 'inner_bags': 10, 'learning_rate': 0.043558038630751306, 'min_samples_leaf': 95, 'max_leaves': 5, 'max_rounds': 9759, 'early_stopping_rounds': 97, 'smoothing_rounds': 399, 'greedy_ratio': 1.191834273756458}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:28:36,400] Trial 87 finished with value: 0.8507973981566462 and parameters: {'max_bins': 558, 'max_interaction_bins': 47, 'interactions': 0.4209275805889161, 'outer_bags': 18, 'inner_bags': 10, 'learning_rate': 0.0491125531992166, 'min_samples_leaf': 93, 'max_leaves': 5, 'max_rounds': 10030, 'early_stopping_rounds': 93, 'smoothing_rounds': 364, 'greedy_ratio': 1.0504728254528148}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:28:54,073] Trial 88 finished with value: 0.8480557698073564 and parameters: {'max_bins': 612, 'max_interaction_bins': 46, 'interactions': 0.23633160517518292, 'outer_bags': 20, 'inner_bags': 10, 'learning_rate': 0.04352983631247056, 'min_samples_leaf': 87, 'max_leaves': 5, 'max_rounds': 8906, 'early_stopping_rounds': 94, 'smoothing_rounds': 400, 'greedy_ratio': 1.3606303154595754}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:29:15,589] Trial 89 finished with value: 0.8557549591344888 and parameters: {'max_bins': 487, 'max_interaction_bins': 40, 'interactions': 0.9777573347928423, 'outer_bags': 17, 'inner_bags': 10, 'learning_rate': 0.04702989924984291, 'min_samples_leaf': 96, 'max_leaves': 6, 'max_rounds': 10683, 'early_stopping_rounds': 98, 'smoothing_rounds': 387, 'greedy_ratio': 1.1693027274106091}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:29:29,924] Trial 90 finished with value: 0.8544349264512349 and parameters: {'max_bins': 673, 'max_interaction_bins': 44, 'interactions': 0.9184133486650605, 'outer_bags': 19, 'inner_bags': 10, 'learning_rate': 0.05274725151076425, 'min_samples_leaf': 88, 'max_leaves': 5, 'max_rounds': 8317, 'early_stopping_rounds': 46, 'smoothing_rounds': 381, 'greedy_ratio': 0.8613081171420116}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:29:42,676] Trial 91 finished with value: 0.8559685274912399 and parameters: {'max_bins': 569, 'max_interaction_bins': 48, 'interactions': 0.9791293108396846, 'outer_bags': 18, 'inner_bags': 9, 'learning_rate': 0.03791196023113062, 'min_samples_leaf': 98, 'max_leaves': 5, 'max_rounds': 7582, 'early_stopping_rounds': 98, 'smoothing_rounds': 335, 'greedy_ratio': 1.34329200491474}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:30:02,787] Trial 92 finished with value: 0.8560154467283558 and parameters: {'max_bins': 532, 'max_interaction_bins': 48, 'interactions': 0.9755235928667229, 'outer_bags': 18, 'inner_bags': 10, 'learning_rate': 0.03742999911742829, 'min_samples_leaf': 92, 'max_leaves': 5, 'max_rounds': 8768, 'early_stopping_rounds': 97, 'smoothing_rounds': 367, 'greedy_ratio': 1.0552920558512442}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:30:18,194] Trial 93 finished with value: 0.8544389317519642 and parameters: {'max_bins': 566, 'max_interaction_bins': 48, 'interactions': 0.9237041795510758, 'outer_bags': 18, 'inner_bags': 10, 'learning_rate': 0.041673574809150064, 'min_samples_leaf': 92, 'max_leaves': 6, 'max_rounds': 8880, 'early_stopping_rounds': 100, 'smoothing_rounds': 365, 'greedy_ratio': 1.3325414205424668}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:30:36,901] Trial 94 finished with value: 0.8547464816294021 and parameters: {'max_bins': 463, 'max_interaction_bins': 46, 'interactions': 0.8501652563625548, 'outer_bags': 18, 'inner_bags': 10, 'learning_rate': 0.038356406973861674, 'min_samples_leaf': 100, 'max_leaves': 5, 'max_rounds': 10427, 'early_stopping_rounds': 98, 'smoothing_rounds': 340, 'greedy_ratio': 1.0265116936055696}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:30:51,509] Trial 95 finished with value: 0.8545695331650345 and parameters: {'max_bins': 533, 'max_interaction_bins': 49, 'interactions': 0.8855569211215009, 'outer_bags': 19, 'inner_bags': 9, 'learning_rate': 0.03756883474444892, 'min_samples_leaf': 97, 'max_leaves': 6, 'max_rounds': 11332, 'early_stopping_rounds': 90, 'smoothing_rounds': 362, 'greedy_ratio': 0.9257583702340819}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:31:02,881] Trial 96 finished with value: 0.8560825355155738 and parameters: {'max_bins': 518, 'max_interaction_bins': 43, 'interactions': 0.9758670739967493, 'outer_bags': 16, 'inner_bags': 10, 'learning_rate': 0.04193648831969198, 'min_samples_leaf': 85, 'max_leaves': 5, 'max_rounds': 9277, 'early_stopping_rounds': 96, 'smoothing_rounds': 287, 'greedy_ratio': 1.1130274528007773}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:31:18,960] Trial 97 finished with value: 0.8560633672906542 and parameters: {'max_bins': 528, 'max_interaction_bins': 42, 'interactions': 0.9689525623977896, 'outer_bags': 16, 'inner_bags': 10, 'learning_rate': 0.03131345618753735, 'min_samples_leaf': 85, 'max_leaves': 5, 'max_rounds': 8180, 'early_stopping_rounds': 94, 'smoothing_rounds': 315, 'greedy_ratio': 1.0770961327828683}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:31:29,432] Trial 98 finished with value: 0.85478324456824 and parameters: {'max_bins': 426, 'max_interaction_bins': 42, 'interactions': 0.9367504504251271, 'outer_bags': 16, 'inner_bags': 9, 'learning_rate': 0.03224098787886866, 'min_samples_leaf': 86, 'max_leaves': 6, 'max_rounds': 8133, 'early_stopping_rounds': 91, 'smoothing_rounds': 295, 'greedy_ratio': 1.0878930066561656}. Best is trial 84 with value: 0.856105565994768.
# [I 2024-10-22 05:31:43,449] Trial 99 finished with value: 0.852576037773419 and parameters: {'max_bins': 519, 'max_interaction_bins': 44, 'interactions': 0.5856851291442076, 'outer_bags': 16, 'inner_bags': 10, 'learning_rate': 0.04144000443831035, 'min_samples_leaf': 92, 'max_leaves': 10, 'max_rounds': 7430, 'early_stopping_rounds': 94, 'smoothing_rounds': 311, 'greedy_ratio': 0.7863119270103212}. Best is trial 84 with value: 0.856105565994768.

# %%
# Print the best hyperparameters and best ROC-AUC score
print("Best hyperparameters:", study_ebm.best_params)
print("Best ROC-AUC score:", study_ebm.best_value)
# Out:
# Best hyperparameters: {'max_bins': 581, 'max_interaction_bins': 47, 'interactions': 0.9998168404207781, 'outer_bags': 18, 'inner_bags': 10, 'learning_rate': 0.04367020510396994, 'min_samples_leaf': 96, 'max_leaves': 5, 'max_rounds': 10124, 'early_stopping_rounds': 97, 'smoothing_rounds': 386, 'greedy_ratio': 1.3695083018257845}
# Best ROC-AUC score: 0.856105565994768

# %%
# Save the best configurations to a JSON file
config_file_path = Path("ebm_apsiii_balanced_data_best_configs.json")

# Load the saved configuration (if it exists)
if config_file_path.exists():
    with open(config_file_path, "r") as config_file:
        saved_configs = json.load(config_file)

    # Compare the new best value with the saved one
    if study_ebm.best_value > saved_configs["best_value"]:
        print("New best value found. Replacing saved configuration.")
        saved_configs["best_params"] = study_ebm.best_params
        saved_configs["best_value"] = study_ebm.best_value

        # Update the saved configuration file
        with open(config_file_path, "w") as config_file:
            json.dump(saved_configs, config_file)
else:
    # If no saved configuration exists, create a new one
    saved_configs = {
        "best_params": study_ebm.best_params,
        "best_value": study_ebm.best_value
    }

    with open(config_file_path, "w") as config_file:
        json.dump(saved_configs, config_file)

# %% [markdown]
# ## Random Forest Optuna Optimization

# %%
def objective_rf(trial: optuna.Trial):
    try:
        # Split the data into training and validation sets (ensure stratification)
        x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(
            X_balanced, y_balanced, test_size=0.2, random_state=42, stratify=y_balanced
        )

        # Initialize StandardScaler
        scaler = StandardScaler()

        # Fit the scaler on the training data and transform both the training and validation sets
        x_train_split = scaler.fit_transform(x_train_split)
        x_valid_split = scaler.transform(x_valid_split)

        # Suggest hyperparameters for RandomForestClassifier, but ensure ranges are sensible
        n_estimators = trial.suggest_int('n_estimators', 100, 300)  # Limit range based on reasonable number of trees
        criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
        max_depth = trial.suggest_int('max_depth', 10, 30)  # Limit max_depth to prevent overfitting
        min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 5)
        min_weight_fraction_leaf = trial.suggest_float('min_weight_fraction_leaf', 0.0, 0.2)  # Tighten the range
        max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])  # Avoid 'auto'

        # Handle None for max_leaf_nodes by using suggest_categorical
        max_leaf_nodes = trial.suggest_categorical('max_leaf_nodes', [None, 20, 50, 100])

        min_impurity_decrease = trial.suggest_float('min_impurity_decrease', 0.0, 0.1)
        bootstrap = trial.suggest_categorical('bootstrap', [True, False])

        # Handle oob_score: If bootstrap is False, oob_score must be False
        if bootstrap:
            oob_score = trial.suggest_categorical('oob_score', [True, False])
            max_samples = trial.suggest_categorical('max_samples', [None, 0.5, 0.75, 1.0])
        else:
            oob_score = False  # Set to False when bootstrap is False
            max_samples = None  # Force max_samples to be None if bootstrap is False

        class_weight = trial.suggest_categorical('class_weight', [None, 'balanced', 'balanced_subsample'])
        ccp_alpha = trial.suggest_float('ccp_alpha', 0.0, 0.05)  # Tighten range

        # Train the model with the sampled hyperparameters
        _, results_rf = train_random_forest_model(
            X_train=x_train_split,
            y_train=y_train_split,
            X_test=x_valid_split,
            n_estimators=n_estimators,
            criterion=criterion,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            min_weight_fraction_leaf=min_weight_fraction_leaf,
            max_features=max_features,
            max_leaf_nodes=max_leaf_nodes,
            min_impurity_decrease=min_impurity_decrease,
            bootstrap=bootstrap,
            oob_score=oob_score,
            class_weight=class_weight,
            ccp_alpha=ccp_alpha,
            max_samples=max_samples,
            random_state=42,  # Fix random state for reproducibility
            verbose=False
        )

        # Calculate the ROC-AUC score on validation data
        roc_auc = roc_auc_score(y_valid_split, results_rf['y_pred_prob'])

        # Maximize ROC-AUC
        return roc_auc

    except Exception as e:
        # Print the error for debugging purposes (optional)
        print(f"Trial failed with error: {e}")
        
        # Return 0.0 ROC-AUC to indicate failure
        return 0.0

# %%
# Create an Optuna study with SQLite storage and TPE pruner
study_name = "Optuna_hyperparameter_optimization"
storage_name = "sqlite:///{}.db".format(study_name)

study_rf = optuna.create_study(
    study_name="Case 15: Random_Forest_APSIII_Balanced_Data",
    direction="maximize",  # Maximize ROC-AUC
    storage=storage_name,
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5),  
)

# Perform a trial with default values first
default_params = {
    'n_estimators': 100,
    'criterion': 'gini',
    'max_depth': 10,
    'min_samples_split': 2,
    'min_samples_leaf': 1,
    'min_weight_fraction_leaf': 0.0,
    'max_features': 'sqrt',
    'max_leaf_nodes': 25,
    'min_impurity_decrease': 0.0,
    'bootstrap': True,
    'oob_score': False,
    'class_weight': None,
    'ccp_alpha': 0.0,
    'max_samples': 0.5
}
study_rf.enqueue_trial(default_params)

# Define the number of trials (hyperparameter combinations) to search
num_trials = 100

# Perform hyperparameter optimization
study_rf.optimize(objective_rf, n_trials=num_trials, n_jobs=1)
# Out:
# [I 2024-10-22 05:31:43,704] A new study created in RDB with name: Case 15: Random_Forest_APSIII_Balanced_Data
# [I 2024-10-22 05:31:44,010] Trial 0 finished with value: 0.0 and parameters: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.0.
# Trial failed with error: '25' not in (None, 20, 50, 100).
# [I 2024-10-22 05:31:45,705] Trial 1 finished with value: 0.7357555055719455 and parameters: {'n_estimators': 104, 'criterion': 'gini', 'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.1070394843024652, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.0007251930380897887, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.04249498865677911}. Best is trial 1 with value: 0.7357555055719455.
# [I 2024-10-22 05:31:49,344] Trial 2 finished with value: 0.5 and parameters: {'n_estimators': 282, 'criterion': 'gini', 'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.09090411894024629, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.06781876464759538, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.013716849734950888}. Best is trial 1 with value: 0.7357555055719455.
# [I 2024-10-22 05:31:52,657] Trial 3 finished with value: 0.7662555845335886 and parameters: {'n_estimators': 211, 'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.16234878917998222, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.046605635268703774, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.75, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.009489815319576034}. Best is trial 3 with value: 0.7662555845335886.
# [I 2024-10-22 05:31:55,470] Trial 4 finished with value: 0.7679468942898144 and parameters: {'n_estimators': 281, 'criterion': 'entropy', 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.130916801377601, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.036316805173271814, 'bootstrap': True, 'oob_score': True, 'max_samples': 1.0, 'class_weight': None, 'ccp_alpha': 0.04435625261690522}. Best is trial 4 with value: 0.7679468942898144.
# [I 2024-10-22 05:31:57,112] Trial 5 finished with value: 0.5 and parameters: {'n_estimators': 144, 'criterion': 'gini', 'max_depth': 26, 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.025647763412103664, 'max_features': None, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.08916866134899622, 'bootstrap': True, 'oob_score': True, 'max_samples': 0.75, 'class_weight': 'balanced', 'ccp_alpha': 0.034302426346222}. Best is trial 4 with value: 0.7679468942898144.
# [I 2024-10-22 05:31:58,069] Trial 6 finished with value: 0.5 and parameters: {'n_estimators': 182, 'criterion': 'entropy', 'max_depth': 16, 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.07156012025347994, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.09052787636202297, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.03135436621042618}. Best is trial 4 with value: 0.7679468942898144.
# [I 2024-10-22 05:32:00,345] Trial 7 finished with value: 0.6469364599092284 and parameters: {'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 6, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.07239801024946838, 'max_features': None, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.06676982049769266, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.00844771607875367}. Best is trial 4 with value: 0.7679468942898144.
# [I 2024-10-22 05:32:02,543] Trial 8 finished with value: 0.7454350300168681 and parameters: {'n_estimators': 246, 'criterion': 'entropy', 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.19982059321297901, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0600504660998496, 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.044459125287540355}. Best is trial 4 with value: 0.7679468942898144.
# [I 2024-10-22 05:32:04,650] Trial 9 finished with value: 0.5 and parameters: {'n_estimators': 124, 'criterion': 'gini', 'max_depth': 27, 'min_samples_split': 9, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.06908403376363526, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.08443284019092957, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.04434914284191242}. Best is trial 4 with value: 0.7679468942898144.
# [I 2024-10-22 05:32:08,836] Trial 10 finished with value: 0.7798245420796894 and parameters: {'n_estimators': 299, 'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.13667338760678885, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.026344697303012383, 'bootstrap': True, 'oob_score': True, 'max_samples': 1.0, 'class_weight': None, 'ccp_alpha': 0.021986635849806133}. Best is trial 10 with value: 0.7798245420796894.
# [I 2024-10-22 05:32:12,941] Trial 11 finished with value: 0.7817023128895155 and parameters: {'n_estimators': 299, 'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.13155804359841922, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.024737106804521982, 'bootstrap': True, 'oob_score': True, 'max_samples': 1.0, 'class_weight': None, 'ccp_alpha': 0.02108418244704113}. Best is trial 11 with value: 0.7817023128895155.
# [I 2024-10-22 05:32:16,941] Trial 12 finished with value: 0.7859022998436788 and parameters: {'n_estimators': 293, 'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.13095065049931287, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.021740749704396607, 'bootstrap': True, 'oob_score': True, 'max_samples': 1.0, 'class_weight': None, 'ccp_alpha': 0.02172989335717691}. Best is trial 12 with value: 0.7859022998436788.
# [I 2024-10-22 05:32:20,531] Trial 13 finished with value: 0.7833715934917296 and parameters: {'n_estimators': 247, 'criterion': 'entropy', 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.17129511338764652, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01602925303054019, 'bootstrap': True, 'oob_score': True, 'max_samples': None, 'class_weight': None, 'ccp_alpha': 0.02014513547027574}. Best is trial 12 with value: 0.7859022998436788.
# [I 2024-10-22 05:32:23,822] Trial 14 finished with value: 0.7872180411332942 and parameters: {'n_estimators': 226, 'criterion': 'entropy', 'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.18483504801351922, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.00734778123258808, 'bootstrap': True, 'oob_score': True, 'max_samples': None, 'class_weight': None, 'ccp_alpha': 0.0016251876831420327}. Best is trial 14 with value: 0.7872180411332942.
# [I 2024-10-22 05:32:29,607] Trial 15 finished with value: 0.7748774234930342 and parameters: {'n_estimators': 227, 'criterion': 'entropy', 'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.19152567661078052, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease':
'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0361082044835153, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.008135748328444983, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.005177166339424738}. Best is trial 41 with value: 0.8174957543812267.
# [I 2024-10-22 05:33:55,147] Trial 56 finished with value: 0.7917475355956798 and parameters: {'n_estimators': 162, 'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.02133106416703038, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.013658217557260662, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0022468873916083832}. Best is trial 41 with value: 0.8174957543812267.
# [I 2024-10-22 05:33:57,047] Trial 57 finished with value: 0.7926512315727557 and parameters: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.05108665144514743, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.004446149499375222, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.010377810910775418}. Best is trial 41 with value: 0.8174957543812267.
# [I 2024-10-22 05:34:00,027] Trial 58 finished with value: 0.7739203711883842 and parameters: {'n_estimators': 258, 'criterion': 'gini', 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.01538100192320264, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.020257181437953485, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.006413231262729206}. Best is trial 41 with value: 0.8174957543812267.
# [I 2024-10-22 05:34:01,821] Trial 59 finished with value: 0.7923943916634815 and parameters: {'n_estimators': 143, 'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.0006746937391800432, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.011190056379626879, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced', 'ccp_alpha': 0.015460277607037934}. Best is trial 41 with value: 0.8174957543812267.
# [I 2024-10-22 05:34:03,583] Trial 60 finished with value: 0.7441472543091314 and parameters: {'n_estimators': 152, 'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.05582905124179342, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.03302484888434988, 'bootstrap': False, 'class_weight': None, 'ccp_alpha': 0.019042783886780015}. Best is trial 41 with value: 0.8174957543812267.
# [I 2024-10-22 05:34:05,788] Trial 61 finished with value: 0.8006989535865752 and parameters: {'n_estimators': 128, 'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.024972010996172495, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.007266708823609141, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.007919083924319444}. Best is trial 41 with value: 0.8174957543812267.
# [I 2024-10-22 05:34:08,042] Trial 62 finished with value: 0.8027728410856884 and parameters: {'n_estimators': 139, 'criterion': 'gini', 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.009393767709498726, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.007074990195250348, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.004701941607074765}. Best is trial 41 with value: 0.8174957543812267.
# [I 2024-10-22 05:34:11,663] Trial 63 finished with value: 0.8125327576381085 and parameters: {'n_estimators': 138, 'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.008126561608130002, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 5.235249847562219e-05, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.00461188556934947}. Best is trial 41 with value: 0.8174957543812267.
# [I 2024-10-22 05:34:14,902] Trial 64 finished with value: 0.811133977881585 and parameters: {'n_estimators': 169, 'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.041894022020793606, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0
 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.014457237244506588, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0021328686186652896, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.00045328047222874864}. Best is trial 75 with value: 0.8213213887636438.
# [I 2024-10-22 05:34:50,665] Trial 76 finished with value: 0.8328319793509581 and parameters: {'n_estimators': 159, 'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01227687719620888, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.00048588755622203106, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.00045743047256008827}. Best is trial 76 with value: 0.8328319793509581.
# [I 2024-10-22 05:34:53,828] Trial 77 finished with value: 0.8269053501662773 and parameters: {'n_estimators': 157, 'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01537518499542015, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0012572626267881863, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0011077929805832878}. Best is trial 76 with value: 0.8328319793509581.
# [I 2024-10-22 05:34:57,509] Trial 78 finished with value: 0.8362949194476804 and parameters: {'n_estimators': 160, 'criterion': 'gini', 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0043396778555745905, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0007340882183458019, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.00023054698848445313}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:00,172] Trial 79 finished with value: 0.7946968673970809 and parameters: {'n_estimators': 160, 'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.015125743442066651, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.012380458055284855, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0006610220903265798}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:02,986] Trial 80 finished with value: 0.6766263237518911 and parameters: {'n_estimators': 177, 'criterion': 'gini', 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.01669061268659153, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.05980593954752759, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 3.2804423608790725e-05}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:07,347] Trial 81 finished with value: 0.822857135500468 and parameters: {'n_estimators': 156, 'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.002772543766903394, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 7.144884338933696e-05, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0026278624184743597}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:10,398] Trial 82 finished with value: 0.8193146615749757 and parameters: {'n_estimators': 157, 'criterion': 'gini', 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.003922112139752654, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0029409837451997334, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.002560108791181435}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:13,752] Trial 83 finished with value: 0.8212920642404463 and parameters: {'n_estimators': 157, 'criterion': 'gini', 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0053804084711286185, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0024581496809205545, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0008691570392061169}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:16,607] Trial 84 finished with value: 0.7979483133106443 and parameters: {'n_estimators': 157, 'criterion': 'gini', 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.004718662259293457, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.00991299658084896, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0010474220458110716}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:20,123] Trial 85 finished with value: 0.8182305840186213 and parameters: {'n_estimators': 164, 'criterion': 'gini', 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.022778756326110504, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.002644773945785164, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.00011300872687545577}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:23,523] Trial 86 finished with value: 0.8004039202739167 and parameters: {'n_estimators': 183, 'criterion': 'gini', 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.024037642581737628, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.00867650263179151, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0018601176741949244}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:26,971] Trial 87 finished with value: 0.8079200101391326 and parameters: {'n_estimators': 166, 'criterion': 'gini', 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.005533380515067634, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.002198918149313382, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.006512702335565143}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:30,944] Trial 88 finished with value: 0.7955556467874054 and parameters: {'n_estimators': 149, 'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01673704517168157, 'max_features': None, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.005607231663717469, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0021652537038285534}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:33,578] Trial 89 finished with value: 0.7357555055719455 and parameters: {'n_estimators': 172, 'criterion': 'gini', 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0003223178626107735, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.044261340396477104, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.00016682872565169796}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:36,651] Trial 90 finished with value: 0.806095667180108 and parameters: {'n_estimators': 163, 'criterion': 'entropy', 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.02117131268912442, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.011424776528738374, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.003565763903448371}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:39,679] Trial 91 finished with value: 0.8193925503695176 and parameters: {'n_estimators': 155, 'criterion': 'gini', 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.011949528903766018, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.002693071059326906, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.001038531915101217}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:42,742] Trial 92 finished with value: 0.8129917937109912 and parameters: {'n_estimators': 153, 'criterion': 'gini', 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01126757129720527, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.004329340335874974, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.002704460435276379}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:45,800] Trial 93 finished with value: 0.8066428913922654 and parameters: {'n_estimators': 145, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.02653241403290267, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0015531588398054587, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0060527685995049275}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:48,870] Trial 94 finished with value: 0.8003200950515081 and parameters: {'n_estimators': 161, 'criterion': 'gini', 'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0005063841378356504, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.008770287179209076, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 3.560286918575617e-05}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:51,812] Trial 95 finished with value: 0.7894140903046546 and parameters: {'n_estimators': 154, 'criterion': 'gini', 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.10102277400536905, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.014525581725658524, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.001870171352544857}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:55,144] Trial 96 finished with value: 0.805845979593565 and parameters: {'n_estimators': 176, 'criterion': 'gini', 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.005876693439080891, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.006611260522047569, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0034300614415569185}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:35:59,428] Trial 97 finished with value: 0.8257850103336759 and parameters: {'n_estimators': 184, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01910480302138539, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0002585068249029269, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0014216582987959647}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:36:04,149] Trial 98 finished with value: 0.8291265755136511 and parameters: {'n_estimators': 199, 'criterion': 'gini', 'max_depth': 21, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.012533400158954381, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0008038858272709664, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0014238995773192234}. Best is trial 78 with value: 0.8362949194476804.
# [I 2024-10-22 05:36:08,505] Trial 99 finished with value: 0.8097650948340775 and parameters: {'n_estimators': 199, 'criterion': 'gini', 'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.018745984880144537, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.004803114866638335, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.005561078504305699}. Best is trial 78 with value: 0.8362949194476804.

# %%
# Print the best hyperparameters and best ROC-AUC score
print("Best hyperparameters:", study_rf.best_params)
print("Best ROC-AUC score:", study_rf.best_value)
# Out:
# Best hyperparameters: {'n_estimators': 160, 'criterion': 'gini', 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0043396778555745905, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0007340882183458019, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.00023054698848445313}
# Best ROC-AUC score: 0.8362949194476804

# %%
# Specify the path where you want to save the JSON file
config_file_path = Path("random_forest_apsiii_balanced_data_best_configs.json")

# Load the saved configuration (if it exists)
if config_file_path.exists():
    with open(config_file_path, "r") as config_file:
        saved_configs = json.load(config_file)

    # Compare the new best value with the saved one
    if study_rf.best_value > saved_configs["best_value"]:
        print("New best value found. Replacing saved configuration.")
        saved_configs["best_params"] = study_rf.best_params
        saved_configs["best_value"] = study_rf.best_value

        # Update the saved configuration file
        with open(config_file_path, "w") as config_file:
            json.dump(saved_configs, config_file)
else:
    # If no saved configuration exists, create a new one
    saved_configs = {
        "best_params": study_rf.best_params,
        "best_value": study_rf.best_value
    }

    with open(config_file_path, "w") as config_file:
        json.dump(saved_configs, config_file)

# %% [markdown]
# ## XGBoost Optuna Optimization

# %%
# Define the objective function for Optuna hyperparameter tuning
def objective_xgboost(trial: optuna.Trial):
    try:
        # Split the data into training and validation sets
        x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(
            X_balanced, y_balanced, test_size=0.2, random_state=42, stratify=y_balanced
        )

        # Initialize StandardScaler
        scaler = StandardScaler()

        # Fit the scaler on the training data and transform both the training and validation sets
        x_train_split = scaler.fit_transform(x_train_split)
        x_valid_split = scaler.transform(x_valid_split)

        # Suggest hyperparameters for XGBoost
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3)
        max_depth = trial.suggest_int('max_depth', 3, 10)
        min_child_weight = trial.suggest_float('min_child_weight', 1, 10)
        subsample = trial.suggest_float('subsample', 0.5, 1.0)
        colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
        reg_alpha = trial.suggest_float('reg_alpha', 0.0, 10.0)
        reg_lambda = trial.suggest_float('reg_lambda', 0.0, 10.0)
        scale_pos_weight = trial.suggest_float('scale_pos_weight', 1.0, 5.0)
        n_estimators = trial.suggest_int('n_estimators', 100, 500)
        gamma = trial.suggest_float('gamma', 0.0, 5.0)
        max_delta_step = trial.suggest_float('max_delta_step', 0.0, 10.0)

        # Train the model with the sampled hyperparameters
        _, results_xgb = train_xgboost_model(
            X_train=x_train_split,
            y_train=y_train_split,
            X_test=x_valid_split,
            objective='binary:logistic',
            booster='gbtree',
            learning_rate=learning_rate,
            max_depth=max_depth,
            min_child_weight=min_child_weight,
            subsample=subsample,
            colsample_bytree=colsample_bytree,
            reg_alpha=reg_alpha,
            reg_lambda=reg_lambda,
            scale_pos_weight=scale_pos_weight,
            n_estimators=n_estimators,
            gamma=gamma,
            max_delta_step=max_delta_step,
            random_state=42,  # Fixed random state for reproducibility
            verbosity=0
        )

        # Calculate the ROC-AUC score on validation data
        roc_auc = roc_auc_score(y_valid_split, results_xgb['y_pred_prob'])

        # Maximize ROC-AUC
        return roc_auc

    except Exception as e:
        # Print the error for debugging purposes (optional)
        print(f"Trial failed with error: {e}")
        
        # Return 0.0 ROC-AUC to indicate failure
        return 0.0

# %%
# Create an Optuna study with SQLite storage and TPE pruner
study_name = "Optuna_hyperparameter_optimization"
storage_name = "sqlite:///{}.db".format(study_name)

study_xgb = optuna.create_study(
    study_name="Case 16: XGBoost_APSIII_Balanced_Data",
    direction="maximize",  # Maximize ROC-AUC
    storage=storage_name,
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5),  
)

# Perform a trial with default values first
default_params = {
    'learning_rate': 0.3,
    'max_depth': 6,
    'min_child_weight': 1,
    'subsample': 1,
    'colsample_bytree': 1,
    'reg_alpha': 0.0,
    'reg_lambda': 1.0,
    'scale_pos_weight': 1.0,
    'n_estimators': 100,
    'gamma': 0.0,
    'max_delta_step': 0.0
}
study_xgb.enqueue_trial(default_params)

# Define the number of trials (hyperparameter combinations) to search
num_trials = 100

# Perform hyperparameter optimization
study_xgb.optimize(objective_xgboost, n_trials=num_trials, n_jobs=1)
# Out:
# [I 2024-10-22 05:36:08,787] A new study created in RDB with name: Case 16: XGBoost_APSIII_Balanced_Data
# [I 2024-10-22 05:36:10,498] Trial 0 finished with value: 0.8884486554777637 and parameters: {'learning_rate': 0.3, 'max_depth': 6, 'min_child_weight': 1.0, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'scale_pos_weight': 1.0, 'n_estimators': 100, 'gamma': 0.0, 'max_delta_step': 0.0}. Best is trial 0 with value: 0.8884486554777637.
# [I 2024-10-22 05:36:12,688] Trial 1 finished with value: 0.8606243319730569 and parameters: {'learning_rate': 0.18364468947758936, 'max_depth': 5, 'min_child_weight': 4.235846919343394, 'subsample': 0.6269084981737464, 'colsample_bytree': 0.6727965957336687, 'reg_alpha': 7.992728691172348, 'reg_lambda': 2.171151775919271, 'scale_pos_weight': 2.7450352752415603, 'n_estimators': 397, 'gamma': 4.970738968984939, 'max_delta_step': 1.8336582537256174}. Best is trial 0 with value: 0.8884486554777637.
# [I 2024-10-22 05:36:14,589] Trial 2 finished with value: 0.8584518139434818 and parameters: {'learning_rate': 0.1752387709770752, 'max_depth': 5, 'min_child_weight': 1.4537519900728824, 'subsample': 0.9118386354295198, 'colsample_bytree': 0.9798224298130038, 'reg_alpha': 3.77910491243727, 'reg_lambda': 6.688612837951819, 'scale_pos_weight': 1.543914898303154, 'n_estimators': 380, 'gamma': 4.652935234052683, 'max_delta_step': 4.572624282500749}. Best is trial 0 with value: 0.8884486554777637.
# [I 2024-10-22 05:36:17,270] Trial 3 finished with value: 0.8677582017115222 and parameters: {'learning_rate': 0.235084900796849, 'max_depth': 3, 'min_child_weight': 7.608252541179547, 'subsample': 0.6268056630840926, 'colsample_bytree': 0.8092258818848466, 'reg_alpha': 8.326979334015068, 'reg_lambda': 2.6431046618712983, 'scale_pos_weight': 4.578150975561725, 'n_estimators': 495, 'gamma': 2.381644711845905, 'max_delta_step': 1.2250892031600258}. Best is trial 0 with value: 0.8884486554777637.
# [I 2024-10-22 05:36:18,953] Trial 4 finished with value: 0.8583239304130497 and parameters: {'learning_rate': 0.03273665369265369, 'max_depth': 7, 'min_child_weight': 9.605470125748141, 'subsample': 0.7169146465075056, 'colsample_bytree': 0.8592509250738825, 'reg_alpha': 7.160018817404724, 'reg_lambda': 3.0360254026077618, 'scale_pos_weight': 2.5497434400676133, 'n_estimators': 183, 'gamma': 4.05121656866334, 'max_delta_step': 1.3626088936032899}. Best is trial 0 with value: 0.8884486554777637.
# [I 2024-10-22 05:36:40,330] Trial 18 finished with value: 0.881777541020001 and parameters: {'learning_rate': 0.20389215474105515, 'max_depth': 6, 'min_child_weight': 1.8235255896970934, 'subsample': 0.579806500463271, 'colsample_bytree': 0.9473225907830808, 'reg_alpha': 0.8134003089504586, 'reg_lambda': 3.8830504446626977, 'scale_pos_weight': 3.7585795177897854, 'n_estimators': 146, 'gamma': 3.027159637810279, 'max_delta_step': 6.754005383948401}. Best is trial 11 with value: 0.9163987168160835.
# [I 2024-10-22 05:36:44,098] Trial 19 finished with value: 0.869846966041916 and parameters: {'learning_rate': 0.01541760717573698, 'max_depth': 8, 'min_child_weight': 3.3193039576170644, 'subsample': 0.7974363914133538, 'colsample_bytree': 0.7165540220061092, 'reg_alpha': 3.0519969002402147, 'reg_lambda': 1.4602776342579502, 'scale_pos_weight': 3.45976159608034, 'n_estimators': 316, 'gamma': 0.49165068120065714, 'max_delta_step': 8.761855303137363}. Best is trial 11 with value: 0.9163987168160835.
# [I 2024-10-22 05:36:45,925] Trial 20 finished with value: 0.8861925983186894 and parameters: {'learning_rate': 0.25751766417025024, 'max_depth': 7, 'min_child_weight': 5.070981748078104, 'subsample': 0.5037798908638941, 'colsample_bytree': 0.8342223256739181, 'reg_alpha': 5.413099284705716, 'reg_lambda': 2.086978151257597, 'scale_pos_weight': 4.326357692005217, 'n_estimators': 145, 'gamma': 1.6854094736359708, 'max_delta_step': 3.9956942685981263}. Best is trial 11 with value: 0.9163987168160835.
# [I 2024-10-22 05:36:47,698] Trial 21 finished with value: 0.9064901749973108 and parameters: {'learning_rate': 0.26303742967043864, 'max_depth': 8, 'min_child_weight': 2.912693524850323, 'subsample': 0.6999240656587851, 'colsample_bytree': 0.8932704302822932, 'reg_alpha': 0.004331184225403163, 'reg_lambda': 0.02740701177564797, 'scale_pos_weight': 1.850353602169553, 'n_estimators': 130, 'gamma': 0.8246114452290887, 'max_delta_step': 9.78812376886629}. Best is trial 11 with value: 0.9163987168160835.
# [I 2024-10-22 05:36:49,838] Trial 22 finished with value: 0.9093435941508877 and parameters: {'learning_rate': 0.2720226738259975, 'max_depth': 9, 'min_child_weight': 3.2697211043445114, 'subsample': 0.669478537822789, 'colsample_bytree': 0.8984272856729828, 'reg_alpha': 0.8926040348450186, 'reg_lambda': 1.0453395739235043, 'scale_pos_weight': 1.0111455024823952, 'n_estimators': 146, 'gamma': 0.4948795697361742, 'max_delta_step': 8.628246306491636}. Best is trial 11 with value: 0.9163987168160835.
# [I 2024-10-22 05:36:52,620] Trial 23 finished with value: 0.9107623288878309 and parameters: {'learning_rate': 0.21803711585559798, 'max_depth': 9, 'min_child_weight': 3.9286702030814804, 'subsample': 0.6524479720372962, 'colsample_bytree': 0.9574315251026955, 'reg_alpha': 1.0990693380025827, 'reg_lambda': 1.1611360088451337, 'scale_pos_weight': 1.000797999032785, 'n_estimators': 213, 'gamma': 0.42535865523349736, 'max_delta_step': 6.967903300362368}. Best is trial 11 with value: 0.9163987168160835.
# [I 2024-10-22 05:39:29,152] Trial 78 finished with value: 0.9284468044566407 and parameters: {'learning_rate': 0.2714876006881422, 'max_depth': 10, 'min_child_weight': 2.7055774648291204, 'subsample': 0.9894326051906177, 'colsample_bytree': 0.7778617829206844, 'reg_alpha': 0.25163447808849, 'reg_lambda': 0.020211015268043808, 'scale_pos_weight': 1.321482414000721, 'n_estimators': 378, 'gamma': 0.02464229894973552, 'max_delta_step': 1.2464789856941318}. Best is trial 71 with value: 0.9337447444732572.
# [I 2024-10-22 05:39:31,242] Trial 79 finished with value: 0.9252409903621021 and parameters: {'learning_rate': 0.27304867505143626, 'max_depth': 9, 'min_child_weight': 2.739546604017481, 'subsample': 0.9910101254646722, 'colsample_bytree': 0.7990192127927945, 'reg_alpha': 0.020201172112970123, 'reg_lambda': 0.8969411893916851, 'scale_pos_weight': 3.8865892352430755, 'n_estimators': 390, 'gamma': 0.12171020144291261, 'max_delta_step': 1.6690374186834256}. Best is trial 71 with value: 0.9337447444732572.
# [I 2024-10-22 05:39:33,396] Trial 80 finished with value: 0.9347503610492515 and parameters: {'learning_rate': 0.2671529802822853, 'max_depth': 10, 'min_child_weight': 1.2997423045245673, 'subsample': 0.966883967000361, 'colsample_bytree': 0.7193589259930178, 'reg_alpha': 0.32500903696003514, 'reg_lambda': 0.297548918401833, 'scale_pos_weight': 4.165436372120891, 'n_estimators': 350, 'gamma': 0.12640379854248848, 'max_delta_step': 2.1692241985166416}. Best is trial 80 with value: 0.9347503610492515.
# [I 2024-10-22 05:39:35,317] Trial 81 finished with value: 0.9339774095317002 and parameters: {'learning_rate': 0.2754064200352903, 'max_depth': 10, 'min_child_weight': 1.4190380391003532, 'subsample': 0.9662212552129477, 'colsample_bytree': 0.7256914666821341, 'reg_alpha': 0.3790983950841649, 'reg_lambda': 0.17449314104122748, 'scale_pos_weight': 4.579502941567194, 'n_estimators': 347, 'gamma': 0.13833097450384843, 'max_delta_step': 2.148740169430002}. Best is trial 80 with value: 0.9347503610492515.
# [I 2024-10-22 05:39:37,287] Trial 82 finished with value: 0.9338644028325487 and parameters: {'learning_rate': 0.29226462937342823, 'max_depth': 10, 'min_child_weight': 1.446001278170252, 'subsample': 0.9549769432712689, 'colsample_bytree': 0.7375274526535489, 'reg_alpha': 0.009695780802805198, 'reg_lambda': 0.4289184329200321, 'scale_pos_weight': 4.5988153988897595, 'n_estimators': 348, 'gamma': 0.14071667495210594, 'max_delta_step': 2.0606709009187325}. Best is trial 80 with value: 0.9347503610492515.
# [I 2024-10-22 05:39:38,639] Trial 83 finished with value: 0.9243597526784018 and parameters: {'learning_rate': 0.2925186418489675, 'max_depth': 10, 'min_child_weight': 1.433565131441848, 'subsample': 0.9626984126690914, 'colsample_bytree': 0.7272598004543224, 'reg_alpha': 0.35157987981285055, 'reg_lambda': 0.29392571441624954, 'scale_pos_weight': 4.452431618531776, 'n_estimators': 355, 'gamma': 0.4927950913943212, 'max_delta_step': 2.353146349594164}. Best is trial 80 with value: 0.9347503610492515.
# [I 2024-10-22 05:39:40,774] Trial 84 finished with value: 0.9337478914952589 and parameters: {'learning_rate': 0.26472184663524967, 'max_depth': 9, 'min_child_weight': 1.3659601880329568, 'subsample': 0.9690899424411636, 'colsample_bytree': 0.743284685891604, 'reg_alpha': 0.028283881619764584, 'reg_lambda': 0.6435279269824707, 'scale_pos_weight': 4.651002207317361, 'n_estimators': 322, 'gamma': 0.002456956357534946, 'max_delta_step': 2.0049364699036096}. Best is trial 80 with value: 0.9347503610492515.
# [I 2024-10-22 05:39:42,626] Trial 85 finished with value: 0.92908042872739 and parameters: {'learning_rate': 0.2624796814049318, 'max_depth': 9, 'min_child_weight': 1.3459204507779559, 'subsample': 0.964972079941069, 'colsample_bytree': 0.7019507353634616, 'reg_alpha': 0.007693471152080744, 'reg_lambda': 5.396061077829444, 'scale_pos_weight': 4.7354420637566115, 'n_estimators': 328, 'gamma': 0.160327856042133, 'max_delta_step': 2.0478204873573485}. Best is trial 80 with value: 0.9347503610492515.
# [I 2024-10-22 05:39:44,569] Trial 86 finished with value: 0.9269852273065383 and parameters: {'learning_rate': 0.265863703937449, 'max_depth': 10, 'min_child_weight': 1.2969418895555833, 'subsample': 0.9100032966635793, 'colsample_bytree': 0.7399686626034618, 'reg_alpha': 0.5120027634280557, 'reg_lambda': 0.30677744691419256, 'scale_pos_weight': 4.211175868795259, 'n_estimators': 355, 'gamma': 0.36713533504103324, 'max_delta_step': 0.27858024606650833}. Best is trial 80 with value: 0.9347503610492515.
# [I 2024-10-22 05:39:45,587] Trial 87 finished with value: 0.877776889300354 and parameters: {'learning_rate': 0.2905254601158878, 'max_depth': 9, 'min_child_weight': 1.709435432878757, 'subsample': 0.9669089434850326, 'colsample_bytree': 0.6599082861681369, 'reg_alpha': 0.0008099031358188291, 'reg_lambda': 0.6194895779804006, 'scale_pos_weight': 4.703808512948513, 'n_estimators': 403, 'gamma': 4.037066056019304, 'max_delta_step': 1.5170009988536401}. Best is trial 80 with value: 0.9347503610492515.
# [I 2024-10-22 05:39:47,580] Trial 88 finished with value: 0.9115018075350007 and parameters: {'learning_rate': 0.2996673513098587, 'max_depth': 10, 'min_child_weight': 1.9722855689822893, 'subsample': 0.9237179013908836, 'colsample_bytree': 0.7117348878639338, 'reg_alpha': 8.70437789921623, 'reg_lambda': 9.49945197889622, 'scale_pos_weight': 4.857065226254531, 'n_estimators': 367, 'gamma': 0.27662594553232644, 'max_delta_step': 2.1471612108511207}. Best is trial 80 with value: 0.9347503610492515.
# [I 2024-10-22 05:39:48,669] Trial 89 finished with value: 0.8733852200969969 and parameters: {'learning_rate': 0.27992152923016417, 'max_depth': 3, 'min_child_weight': 1.6017654749095154, 'subsample': 0.91285749767712, 'colsample_bytree': 0.7459812870531017, 'reg_alpha': 0.6664140222467896, 'reg_lambda': 1.03413427823696, 'scale_pos_weight': 4.556456515399221, 'n_estimators': 337, 'gamma': 0.1256339364688181, 'max_delta_step': 0.914324352127571}. Best is trial 80 with value: 0.9347503610492515.
# [I 2024-10-22 05:39:49,503] Trial 90 finished with value: 0.8853604970921517 and parameters: {'learning_rate': 0.25821836371121626, 'max_depth': 9, 'min_child_weight': 1.3116701371309907, 'subsample': 0.9776220785354134, 'colsample_bytree': 0.7959506631922987, 'reg_alpha': 0.40350612544278, 'reg_lambda': 0.28199002038815646, 'scale_pos_weight': 4.223026139471001, 'n_estimators': 322, 'gamma': 3.230732699886648, 'max_delta_step': 2.588249667611616}. Best is trial 80 with value: 0.9347503610492515.
# [I 2024-10-22 05:40:02,452] Trial 97 finished with value: 0.9306499344275053 and parameters: {'learning_rate': 0.2933680425587713, 'max_depth': 9, 'min_child_weight': 1.2780470195434777, 'subsample': 0.9368549823109564, 'colsample_bytree': 0.6850277428843539, 'reg_alpha': 1.0943101316828074, 'reg_lambda': 2.0175208804656686, 'scale_pos_weight': 4.528880020420372, 'n_estimators': 365, 'gamma': 0.22520410140990949, 'max_delta_step': 0.6045545248553036}. Best is trial 95 with value: 0.9370923176043267.
# [I 2024-10-22 05:40:03,973] Trial 98 finished with value: 0.9220818809349974 and parameters: {'learning_rate': 0.28025060607821856, 'max_depth': 10, 'min_child_weight': 1.5029605269905408, 'subsample': 0.9541515049405386, 'colsample_bytree': 0.665979425809301, 'reg_alpha': 1.1182060106003424, 'reg_lambda': 9.890534616368939, 'scale_pos_weight': 4.287142645483974, 'n_estimators': 390, 'gamma': 0.3682981944962417, 'max_delta_step': 1.1159481312197466}. Best is trial 95 with value: 0.9370923176043267.
# [I 2024-10-22 05:40:05,394] Trial 99 finished with value: 0.9051787966245615 and parameters: {'learning_rate': 0.2758907281468775, 'max_depth': 9, 'min_child_weight': 1.2150993411023072, 'subsample': 0.8936973533716074, 'colsample_bytree': 0.7031794895093167, 'reg_alpha': 6.860951163609897, 'reg_lambda': 1.194212284197807, 'scale_pos_weight': 4.428600187686403, 'n_estimators': 377, 'gamma': 0.7255114382671644, 'max_delta_step': 0.24153325388541674}. Best is trial 95 with value: 0.9370923176043267.

# %%
# Print the best hyperparameters and best ROC-AUC score
print("Best hyperparameters:", study_xgb.best_params)
print("Best ROC-AUC score:", study_xgb.best_value)
# Out:
# Best hyperparameters: {'learning_rate': 0.2896027779817393, 'max_depth': 10, 'min_child_weight': 1.2646569686590456, 'subsample': 0.9323226684735562, 'colsample_bytree': 0.6961040747673508, 'reg_alpha': 1.046220932209122, 'reg_lambda': 0.8626759113789945, 'scale_pos_weight': 4.541731121439532, 'n_estimators': 365, 'gamma': 0.004571785264911518, 'max_delta_step': 0.6586642621092984}
# Best ROC-AUC score: 0.9370923176043267

# %%
# Save the best configurations to a JSON file
config_file_path = Path("xgboost_apsiii_balanced_data_best_configs.json")

# Load the saved configuration (if it exists)
if config_file_path.exists():
    with open(config_file_path, "r") as config_file:
        saved_configs = json.load(config_file)

    # Compare the new best value with the saved one
    if study_xgb.best_value > saved_configs["best_value"]:
        print("New best value found. Replacing saved configuration.")
        saved_configs["best_params"] = study_xgb.best_params
        saved_configs["best_value"] = study_xgb.best_value

        # Update the saved configuration file
        with open(config_file_path, "w") as config_file:
            json.dump(saved_configs, config_file)
else:
    # If no saved configuration exists, create a new one
    saved_configs = {
        "best_params": study_xgb.best_params,
        "best_value": study_xgb.best_value
    }

    with open(config_file_path, "w") as config_file:
        json.dump(saved_configs, config_file)

# %% [markdown]
# # End
