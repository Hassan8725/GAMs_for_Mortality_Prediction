# %%
from pathlib import Path
import pandas as pd
import numpy as np
import json
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('../src') 

from data_pipeline.extractor import execute_query
from gams.logistic_gam import train_logistic_gam_model
from gams.ebm_gam import train_ebm_model
from ml_models.random_forest import train_random_forest_model
from ml_models.xgb_model import train_xgboost_model

import optuna
from pygam import s, l, te
from sklearn.metrics import roc_auc_score

# %%
query = """
SELECT s.*, a.hospital_expire_flag as mortality
FROM apsiii s
LEFT JOIN admissions a
ON s.subject_id = a.subject_id
AND s.hadm_id = a.hadm_id;
"""

df = execute_query(query)

# Exclude specific columns
df_filtered = df.drop(columns=['subject_id', 'hadm_id', 'icustay_id', 'apsiii', 'apsiii_prob'])

# Replace NaNs with 0
df_filtered = df_filtered.fillna(0)

# Separate features and target variable
y_balanced = df_filtered['mortality']
X_balanced = df_filtered.drop(columns=['mortality'])

# %% [markdown]
# ## LogisticGam Optuna Optimization

# %%
# Define the objective function for Optuna hyperparameter tuning
def objective_gam(trial: optuna.Trial):
    try:
        # Suggest using 'auto' or custom term setup
        terms_option = trial.suggest_categorical("terms_option", ['auto', 'custom'])

        if terms_option == 'auto':
            terms = 'auto'
        else:
            # Predefined set of terms focusing on 15 continuous features
            predefined_terms = [
                # Spline terms for features 0-14
                s(0, n_splines=10, spline_order=3),   # Spline term for feature 0
                s(1, n_splines=15, spline_order=3),   # Spline term for feature 1
                s(2, n_splines=20, spline_order=3),   # Spline term for feature 2
                s(3, n_splines=12, spline_order=3),   # Spline term for feature 3
                s(4, n_splines=18, spline_order=3),   # Spline term for feature 4
                s(5, n_splines=10, spline_order=3),   # Spline term for feature 5
                s(6, n_splines=14, spline_order=3),   # Spline term for feature 6
                s(7, n_splines=16, spline_order=3),   # Spline term for feature 7
                s(8, n_splines=12, spline_order=3),   # Spline term for feature 8
                s(9, n_splines=10, spline_order=3),   # Spline term for feature 9
                s(10, n_splines=15, spline_order=3),  # Spline term for feature 10
                s(11, n_splines=10, spline_order=3),  # Spline term for feature 11
                s(12, n_splines=18, spline_order=3),  # Spline term for feature 12
                s(13, n_splines=12, spline_order=3),  # Spline term for feature 13
                s(14, n_splines=20, spline_order=3),  # Spline term for feature 14
                s(15, n_splines=18, spline_order=3),  # Spline term for feature 14


                # Linear terms for features 0-14
                l(0), l(1), l(2), l(3), l(4), l(5), l(6), l(7), l(8), l(9), 
                l(10), l(11), l(12), l(13), l(14), l(15),

                # Interaction terms between pairs of features
                te(s(0), s(1)),  # Interaction between spline terms of features 0 and 1
                te(s(2), s(3)),  # Interaction between spline terms of features 2 and 3
                te(s(4), s(5)),  # Interaction between spline terms of features 4 and 5
                te(l(6), l(7)),  # Interaction between linear terms of features 6 and 7
                te(l(8), l(9)),  # Interaction between linear terms of features 8 and 9
                te(s(10), l(11)), # Interaction between spline term of feature 10 and linear term of feature 11
                te(s(12), s(13)), # Interaction between spline terms of features 12 and 13
                te(l(13), l(14)),  # Interaction between linear terms of features 13 and 14
                te(l(14), l(15))  # Interaction between linear terms of features 13 and 14

            ]
            
            # Let Optuna select one term from the predefined set
            selected_term_index = trial.suggest_int("selected_term", 0, len(predefined_terms) - 1)
            terms = predefined_terms[selected_term_index]

        # Hyperparameters for the LogisticGAM
        max_iter = trial.suggest_int("max_iter", 50, 500)
        tol = trial.suggest_loguniform("tol", 1e-5, 1e-1)
        fit_intercept = trial.suggest_categorical("fit_intercept", [True, False])

        # Split the data into training and validation sets
        x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(
            X_balanced, y_balanced, test_size=0.2, random_state=42, stratify=y_balanced
        )

        # Initialize StandardScaler
        scaler = StandardScaler()

        # Fit the scaler on the training data and transform both the training and validation sets
        x_train_split = scaler.fit_transform(x_train_split)
        x_valid_split = scaler.transform(x_valid_split)

        # Train the model with the sampled hyperparameters
        _, results = train_logistic_gam_model(
            X_train=x_train_split,
            y_train=y_train_split,
            X_test=x_valid_split,
            terms=terms,
            max_iter=max_iter,
            tol=tol,
            fit_intercept=fit_intercept,
            verbose=False,
            include_summary = False,
        )

        # Calculate the ROC-AUC score on validation data
        roc_auc = roc_auc_score(y_valid_split, results['y_pred_prob'])

        # Maximize ROC-AUC
        return roc_auc

    except Exception as e:
        # Print the error for debugging purposes (optional)
        print(f"Trial failed with error: {e}")

        # Return 0.0 ROC-AUC to indicate failure
        return 0.0  # Low ROC-AUC to signal failure

# %%
# Create an Optuna study with SQLite storage and TPE pruner
study_name = "Optuna_hyperparameter_optimization"
storage_name = "sqlite:///{}.db".format(study_name)

study_gam = optuna.create_study(
    study_name="Case 9: LogisticGam_APSIII",
    direction="maximize",  # Maximize ROC-AUC
    storage=storage_name,
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5),
)

# Perform a trial with default values first
default_params = {
    'terms_option': 'auto',
    'max_iter': 100,
    'tol': 0.0001,
    'fit_intercept': True
}
study_gam.enqueue_trial(default_params)

# Define the number of trials (hyperparameter combinations) to search
num_trials = 100

# Perform hyperparameter optimization
study_gam.optimize(objective_gam, n_trials=num_trials, n_jobs=1)
# Out:
# [I 2024-10-22 04:10:23,954] A new study created in RDB with name: Case 9: LogisticGam_APSIII
# [I 2024-10-22 04:10:32,320] Trial 0 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 100, 'tol': 0.0001, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:10:41,413] Trial 1 finished with value: 0.8276883895450887 and parameters: {'terms_option': 'auto', 'max_iter': 147, 'tol': 0.011486703727907424, 'fit_intercept': False}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:10:51,037] Trial 2 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 69, 'tol': 3.415874006190321e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:10:59,623] Trial 3 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 247, 'tol': 0.004671311248686663, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:11:08,794] Trial 4 finished with value: 0.6191155660620967 and parameters: {'terms_option': 'custom', 'selected_term': 38, 'max_iter': 445, 'tol': 0.0013382682924505422, 'fit_intercept': False}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:11:08,982] Trial 5 finished with value: 0.5822632567997758 and parameters: {'terms_option': 'custom', 'selected_term': 31, 'max_iter': 96, 'tol': 3.619204139444521e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:11:18,550] Trial 6 finished with value: 0.5829285155042256 and parameters: {'terms_option': 'custom', 'selected_term': 34, 'max_iter': 309, 'tol': 3.3316087241245706e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04
finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 71, 'tol': 0.00047896743142567926, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:20:39,361] Trial 74 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 136, 'tol': 0.0002674276464554448, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:20:49,174] Trial 75 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 108, 'tol': 7.04239371729133e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:21:01,285] Trial 76 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 200, 'tol': 2.801453310488012e-05, 'fit_intercept': False}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:21:01,464] Trial 77 finished with value: 0.5649820240363527 and parameters: {'terms_option': 'custom', 'selected_term': 27, 'max_iter': 87, 'tol': 0.00033184168970444377, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:21:10,133] Trial 78 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 153, 'tol': 0.00021184908289148435, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:21:20,544] Trial 79 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 407, 'tol': 0.0007040482827042159, 'fit_intercept': False}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:21:29,141] Trial 80 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 121, 'tol': 8.552791278837608e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:21:38,843] Trial 81 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 237, 'tol': 6.135589402484276e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:21:48,568] Trial 82 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 191, 'tol': 3.4809477729382175e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:21:57,189] Trial 83 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 213, 'tol': 0.00010421097021894085, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:22:07,086] Trial 84 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 168, 'tol': 2.265486854027248e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:22:16,751] Trial 85 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 255, 'tol': 4.339271580041915e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:22:25,410] Trial 86 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 222, 'tol': 0.0001752997013542977, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:22:32,962] Trial 87 finished with value: 0.8276883895450887 and parameters: {'terms_option': 'auto', 'max_iter': 271, 'tol': 0.016084452507312805, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:22:43,495] Trial 88 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 64, 'tol': 0.00011508124862467787, 'fit_intercept': False}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:22:43,685] Trial 89 finished with value: 0.5659414192231602 and parameters: {'terms_option': 'custom', 'selected_term': 19, 'max_iter': 104, 'tol': 1.4550570615383858e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:22:52,356] Trial 90 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 160, 'tol': 0.001406227209679867, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:23:01,023] Trial 91 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 292, 'tol': 0.00032408929362607566, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:23:09,608] Trial 92 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 81, 'tol': 0.0002670020551449417, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:23:18,196] Trial 93 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 146, 'tol': 0.0005402040512394248, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:23:26,828] Trial 94 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 119, 'tol': 0.0001329699422639012, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:23:36,582] Trial 95 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 134, 'tol': 1.0021258225753017e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:23:45,237] Trial 96 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 90, 'tol': 7.641186746800163e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:23:55,779] Trial 97 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 54, 'tol': 0.0011292357026669313, 'fit_intercept': False}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:24:04,280] Trial 98 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 71, 'tol': 0.0001652932207767367, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.
# [I 2024-10-22 04:24:14,011] Trial 99 finished with value: 0.8276893535883412 and parameters: {'terms_option': 'auto', 'max_iter': 174, 'tol': 1.8770287280061158e-05, 'fit_intercept': True}. Best is trial 0 with value: 0.8276893535883412.

# %%
# Print the best hyperparameters and best ROC-AUC score
print("Best hyperparameters:", study_gam.best_params)
print("Best ROC-AUC score:", study_gam.best_value)
# Out:
# Best hyperparameters: {'terms_option': 'auto', 'max_iter': 100, 'tol': 0.0001, 'fit_intercept': True}
# Best ROC-AUC score: 0.8276893535883412

# %%
# Save the best configurations to a JSON file
config_file_path = Path("logisticgam_apsiii_best_configs.json")

# Load the saved configuration (if it exists)
if config_file_path.exists():
    with open(config_file_path, "r") as config_file:
        saved_configs = json.load(config_file)

    # Compare the new best value with the saved one
    if study_gam.best_value > saved_configs["best_value"]:
        print("New best value found. Replacing saved configuration.")
        saved_configs["best_params"] = study_gam.best_params
        saved_configs["best_value"] = study_gam.best_value

        # Update the saved configuration file
        with open(config_file_path, "w") as config_file:
            json.dump(saved_configs, config_file)
else:
    # If no saved configuration exists, create a new one
    saved_configs = {
        "best_params": study_gam.best_params,
        "best_value": study_gam.best_value
    }

    with open(config_file_path, "w") as config_file:
        json.dump(saved_configs, config_file)

# %% [markdown]
# ## EBM Optuna Optimization

# %%
# Define the objective function for Optuna hyperparameter tuning
def objective_ebm(trial: optuna.Trial):
    try:
        # Split the data into training and validation sets
        x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(
            X_balanced, y_balanced, test_size=0.2, random_state=42, stratify=y_balanced
        )

        # Initialize StandardScaler
        scaler = StandardScaler()

        # Fit the scaler on the training data and transform both the training and validation sets
        x_train_split = scaler.fit_transform(x_train_split)
        x_valid_split = scaler.transform(x_valid_split)

        # Suggest hyperparameters for EBM
        max_bins = trial.suggest_int('max_bins', 64, 1024)
        max_interaction_bins = trial.suggest_int('max_interaction_bins', 16, 64)
        interactions = trial.suggest_float('interactions', 0.0, 1.0)
        outer_bags = trial.suggest_int('outer_bags', 1, 20)
        inner_bags = trial.suggest_int('inner_bags', 0, 10)
        learning_rate = trial.suggest_float('learning_rate', 0.001, 0.1)
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 100)
        max_leaves = trial.suggest_int('max_leaves', 1, 10)
        max_rounds = trial.suggest_int('max_rounds', 5000, 25000)
        early_stopping_rounds = trial.suggest_int('early_stopping_rounds', 10, 100)
        smoothing_rounds = trial.suggest_int('smoothing_rounds', 50, 500)
        greedy_ratio = trial.suggest_float('greedy_ratio', 0.0, 3.0)

        # Train the model with the sampled hyperparameters
        _, results_ebm = train_ebm_model(
            X_train=x_train_split,
            y_train=y_train_split,
            X_test=x_valid_split,
            max_bins=max_bins,
            max_interaction_bins=max_interaction_bins,
            interactions=interactions,
            outer_bags=outer_bags,
            inner_bags=inner_bags,
            learning_rate=learning_rate,
            min_samples_leaf=min_samples_leaf,
            max_leaves=max_leaves,
            max_rounds=max_rounds,
            early_stopping_rounds=early_stopping_rounds,
            smoothing_rounds=smoothing_rounds,
            greedy_ratio=greedy_ratio,
            random_state=42,  # Fixed random state for reproducibility
        )

        # Calculate the ROC-AUC score on validation data
        roc_auc = roc_auc_score(y_valid_split, results_ebm['y_pred_prob'])

        # Maximize ROC-AUC
        return roc_auc

    except Exception as e:
        # Print the error for debugging purposes (optional)
        print(f"Trial failed with error: {e}")
        
        # Return 0.0 ROC-AUC to indicate failure
        return 0.0

# %%
# Create an Optuna study with SQLite storage and TPE pruner
study_name = "Optuna_hyperparameter_optimization"
storage_name = "sqlite:///{}.db".format(study_name)

study_ebm = optuna.create_study(
    study_name="Case 10: EBM_APSIII",
    direction="maximize",  # Maximize ROC-AUC
    storage=storage_name,
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5),  
)

# Perform a trial with default values first
default_params = {
    'max_bins': 1024,
    'max_interaction_bins': 32,
    'interactions': 0.9,
    'outer_bags': 14,
    'inner_bags': 0,
    'learning_rate': 0.01,
    'min_samples_leaf': 2,
    'max_leaves': 3,
    'max_rounds': 25000,
    'early_stopping_rounds': 50,
    'smoothing_rounds': 200,
    'greedy_ratio': 1.5
}
study_ebm.enqueue_trial(default_params)

# Define the number of trials (hyperparameter combinations) to search
num_trials = 100

# Perform hyperparameter optimization
study_ebm.optimize(objective_ebm, n_trials=num_trials, n_jobs=1)
# Out:
# [I 2024-10-22 04:24:14,079] A new study created in RDB with name: Case 10: EBM_APSIII
# [I 2024-10-22 04:24:20,914] Trial 0 finished with value: 0.8431681697707711 and parameters: {'max_bins': 1024, 'max_interaction_bins': 32, 'interactions': 0.9, 'outer_bags': 14, 'inner_bags': 0, 'learning_rate': 0.01, 'min_samples_leaf': 2, 'max_leaves': 3, 'max_rounds': 25000, 'early_stopping_rounds': 50, 'smoothing_rounds': 200, 'greedy_ratio': 1.5}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:24:27,648] Trial 1 finished with value: 0.8422100484982615 and parameters: {'max_bins': 1015, 'max_interaction_bins': 36, 'interactions': 0.39032640505340577, 'outer_bags': 16, 'inner_bags': 3, 'learning_rate': 0.01107535866764384, 'min_samples_leaf': 24, 'max_leaves': 7, 'max_rounds': 15945, 'early_stopping_rounds': 35, 'smoothing_rounds': 462, 'greedy_ratio': 1.629191529298818}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:24:32,522] Trial 2 finished with value: 0.8429754299805057 and parameters: {'max_bins': 473, 'max_interaction_bins': 36, 'interactions': 0.8159479114742783, 'outer_bags': 19, 'inner_bags': 0, 'learning_rate': 0.07896976201939626, 'min_samples_leaf': 53, 'max_leaves': 2, 'max_rounds': 21504, 'early_stopping_rounds': 55, 'smoothing_rounds': 365, 'greedy_ratio': 0.13502057599327866}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:24:34,142] Trial 3 finished with value: 0.8363987269120249 and parameters: {'max_bins': 429, 'max_interaction_bins': 60, 'interactions': 0.042698817874924244, 'outer_bags': 7, 'inner_bags': 1, 'learning_rate': 0.01295785651519243, 'min_samples_leaf': 98, 'max_leaves': 7, 'max_rounds': 18869, 'early_stopping_rounds': 77, 'smoothing_rounds': 388, 'greedy_ratio': 2.21182257012936}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:24:35,799] Trial 4 finished with value: 0.8423467360594181 and parameters: {'max_bins': 926, 'max_interaction_bins': 55, 'interactions': 0.5167983574597198, 'outer_bags': 11, 'inner_bags': 0, 'learning_rate': 0.07312196842541521, 'min_samples_leaf': 63, 'max_leaves': 7, 'max_rounds': 20908, 'early_stopping_rounds': 54, 'smoothing_rounds': 341, 'greedy_ratio': 0.8390310153679325}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:24:40,833] Trial 5 finished with value: 0.8398365051504012 and parameters: {'max_bins': 81, 'max_interaction_bins': 50, 'interactions': 0.125918488853336, 'outer_bags': 7, 'inner_bags': 5, 'learning_rate': 0.026369640440266538, 'min_samples_leaf': 17, 'max_leaves': 8, 'max_rounds': 8636, 'early_stopping_rounds': 87, 'smoothing_rounds': 477, 'greedy_ratio': 1.662223202373847}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:24:42,242] Trial 6 finished with value: 0.5 and parameters: {'max_bins': 941, 'max_interaction_bins': 31, 'interactions': 0.562160756443533, 'outer_bags': 12, 'inner_bags': 2, 'learning_rate': 0.0653527100554523, 'min_samples_leaf': 53, 'max_leaves': 1, 'max_rounds': 8335, 'early_stopping_rounds': 55, 'smoothing_rounds': 389, 'greedy_ratio': 1.6760615666720189}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:24:45,820] Trial 7 finished with value: 0.84268001958385 and parameters: {'max_bins': 594, 'max_interaction_bins': 39, 'interactions': 0.9037617148513677, 'outer_bags': 10, 'inner_bags': 9, 'learning_rate': 0.05727153289626241, 'min_samples_leaf': 32, 'max_leaves': 4, 'max_rounds': 22642, 'early_stopping_rounds': 26, 'smoothing_rounds': 154, 'greedy_ratio': 1.6451476775621647}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:24:46,441] Trial 8 finished with value: 0.5 and parameters: {'max_bins': 964, 'max_interaction_bins': 24, 'interactions': 0.6119927586096368, 'outer_bags': 2, 'inner_bags': 5, 'learning_rate': 0.09603528240324766, 'min_samples_leaf': 77, 'max_leaves': 1, 'max_rounds': 21252, 'early_stopping_rounds': 69, 'smoothing_rounds': 118, 'greedy_ratio': 1.9674055333512048}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:24:48,022] Trial 9 finished with value: 0.8409151318294718 and parameters: {'max_bins': 997, 'max_interaction_bins': 59, 'interactions': 0.833797197538631, 'outer_bags': 1, 'inner_bags': 7, 'learning_rate': 0.08857650904230026, 'min_samples_leaf': 80, 'max_leaves': 3, 'max_rounds': 5219, 'early_stopping_rounds': 68, 'smoothing_rounds': 143, 'greedy_ratio': 2.5904256681706768}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:25:00,740] Trial 10 finished with value: 0.840459690252903 and parameters: {'max_bins': 707, 'max_interaction_bins': 16, 'interactions': 0.2848026888966467, 'outer_bags': 16, 'inner_bags': 10, 'learning_rate': 0.03413308050147247, 'min_samples_leaf': 3, 'max_leaves': 10, 'max_rounds': 24797, 'early_stopping_rounds': 100, 'smoothing_rounds': 237, 'greedy_ratio': 0.8255201591995345}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:25:03,639] Trial 11 finished with value: 0.8427753910056142 and parameters: {'max_bins': 346, 'max_interaction_bins': 47, 'interactions': 0.8009388491461557, 'outer_bags': 20, 'inner_bags': 0, 'learning_rate': 0.038443994515165954, 'min_samples_leaf': 42, 'max_leaves': 3, 'max_rounds': 17288, 'early_stopping_rounds': 41, 'smoothing_rounds': 250, 'greedy_ratio': 0.14121304436979987}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:25:05,538] Trial 12 finished with value: 0.8427908845578863 and parameters: {'max_bins': 733, 'max_interaction_bins': 29, 'interactions': 0.9892299897608067, 'outer_bags': 19, 'inner_bags': 3, 'learning_rate': 0.08031511473205476, 'min_samples_leaf': 6, 'max_leaves': 4, 'max_rounds': 24123, 'early_stopping_rounds': 14, 'smoothing_rounds': 59, 'greedy_ratio': 0.23211826803103536}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:25:55,287] Trial 13 finished with value: 0.8410562264454967 and parameters: {'max_bins': 319, 'max_interaction_bins': 41, 'interactions': 0.7253138974784021, 'outer_bags': 16, 'inner_bags': 2, 'learning_rate': 0.0012039020107981885, 'min_samples_leaf': 48, 'max_leaves': 2, 'max_rounds': 12732, 'early_stopping_rounds': 45, 'smoothing_rounds': 316, 'greedy_ratio': 0.9410143911997517}. Best is trial 0 with value: 0.8431681697707711.
# [I 2024-10-22 04:25:57,248] Trial 14 finished with value: 0.8435536493513022 and parameters: {'max_bins': 139, 'max_interaction_bins': 22, 'interactions': 0.6876933018252362, 'outer_bags': 14, 'inner_bags': 0, 'learning_rate': 0.04904068519127522, 'min_samples_leaf': 66, 'max_leaves': 5, 'max_rounds': 19893, 'early_stopping_rounds': 63, 'smoothing_rounds': 212, 'greedy_ratio': 2.9411379504737303}. Best is trial 14 with value: 0.8435536493513022.
# [I 2024-10-22 04:26:02,615] Trial 15 finished with value: 0.8422117011438373 and parameters: {'max_bins': 88, 'max_interaction_bins': 18, 'interactions': 0.684657607016833, 'outer_bags': 14, 'inner_bags': 4, 'learning_rate': 0.047042754369184064, 'min_samples_leaf': 70, 'max_leaves': 5, 'max_rounds': 13374, 'early_stopping_rounds': 77, 'smoothing_rounds': 203, 'greedy_ratio': 2.9355837778030534}. Best is trial 14 with value: 0.8435536493513022.
# [I 2024-10-22 04:26:08,572] Trial 16 finished with value: 0.8410324696653462 and parameters: {'max_bins': 217, 'max_interaction_bins': 23, 'interactions': 0.42012935875968893, 'outer_bags': 9, 'inner_bags': 7, 'learning_rate': 0.02074617124908424, 'min_samples_leaf': 95, 'max_leaves': 5, 'max_rounds': 18751, 'early_stopping_rounds': 64, 'smoothing_rounds': 213, 'greedy_ratio': 1.2004201627666906}. Best is trial 14 with value: 0.8435536493513022.
# [I 2024-10-22 04:26:10,660] Trial 17 finished with value: 0.843116180295369 and parameters: {'max_bins': 762, 'max_interaction_bins': 28, 'interactions': 0.995701105166593, 'outer_bags': 13, 'inner_bags': 1, 'learning_rate': 0.054732900769343805, 'min_samples_leaf': 36, 'max_leaves': 6, 'max_rounds': 24969, 'early_stopping_rounds': 24, 'smoothing_rounds': 300, 'greedy_ratio': 2.2642495048015703}. Best is trial 14 with value: 0.8435536493513022.
# [I 2024-10-22 04:26:17,914] Trial 18 finished with value: 0.8434712925134467 and parameters: {'max_bins': 606, 'max_interaction_bins': 22, 'interactions': 0.6899544862969282, 'outer_bags': 14, 'inner_bags': 2, 'learning_rate': 0.04223622556252934, 'min_samples_leaf': 87, 'max_leaves': 9, 'max_rounds': 18587, 'early_stopping_rounds': 46, 'smoothing_rounds': 77, 'greedy_ratio': 2.9450235975814296}. Best is trial 14 with value: 0.8435536493513022.
# [I 2024-10-22 04:26:20,842] Trial 19 finished with value: 0.8421315478334161 and parameters: {'max_bins': 583, 'max_interaction_bins': 22, 'interactions': 0.6569476450771758, 'outer_bags': 4, 'inner_bags': 2, 'learning_rate': 0.041929694393224574, 'min_samples_leaf': 83, 'max_leaves': 10, 'max_rounds': 13861, 'early_stopping_rounds': 34, 'smoothing_rounds': 64, 'greedy_ratio': 2.970734572376328}. Best is trial 14 with value: 0.8435536493513022.
# [I 2024-10-22 04:26:32,832] Trial 20 finished with value: 0.8410860429260916 and parameters: {'max_bins': 202, 'max_interaction_bins': 21, 'interactions': 0.3989385182692554, 'outer_bags': 18, 'inner_bags': 4, 'learning_rate': 0.0617807429496251, 'min_samples_leaf': 90, 'max_leaves': 9, 'max_rounds': 19376, 'early_stopping_rounds': 61, 'smoothing_rounds': 95, 'greedy_ratio': 2.614702759258729}. Best is trial 14 with value: 0.8435536493513022.
# [I 2024-10-22 04:26:36,432] Trial 21 finished with value: 0.843029829564039 and parameters: {'max_bins': 828, 'max_interaction_bins': 27, 'interactions': 0.7479675583194018, 'outer_bags': 14, 'inner_bags': 1, 'learning_rate': 0.02878711212556901, 'min_samples_leaf': 64, 'max_leaves': 6, 'max_rounds': 15997, 'early_stopping_rounds': 47, 'smoothing_rounds': 162, 'greedy_ratio': 2.557693315759546}. Best is trial 14 with value: 0.8435536493513022.
# [I 2024-10-22 04:26:39,999] Trial 22 finished with value: 0.8433863189867631 and parameters: {'max_bins': 627, 'max_interaction_bins': 33, 'interactions': 0.9074460463278665, 'outer_bags': 15, 'inner_bags': 0, 'learning_rate': 0.05004632470999994, 'min_samples_leaf': 71, 'max_leaves': 4, 'max_rounds': 22687, 'early_stopping_rounds': 46, 'smoothing_rounds': 188, 'greedy_ratio': 1.2191453792287161}. Best is trial 14 with value: 0.8435536493513022.
# [I 2024-10-22 04:26:42,630] Trial 23 finished with value: 0.8416311405251419 and parameters: {'max_bins': 656, 'max_interaction_bins': 19, 'interactions': 0.595400780897255, 'outer_bags': 17, 'inner_bags': 1, 'learning_rate': 0.049127490081101434, 'min_samples_leaf': 71, 'max_leaves': 4, 'max_rounds': 22714, 'early_stopping_rounds': 39, 'smoothing_rounds': 112, 'greedy_ratio': 1.1677634413796092}. Best is trial 14 with value: 0.8435536493513022.
# [I 2024-10-22 04:26:47,291] Trial 24 finished with value: 0.8435701069468268 and parameters: {'max_bins': 497, 'max_interaction_bins': 26, 'interactions': 0.9276151941461146, 'outer_bags': 15, 'inner_bags': 3, 'learning_rate': 0.04658093553294598, 'min_samples_leaf': 89, 'max_leaves': 5, 'max_rounds': 19929, 'early_stopping_rounds': 26, 'smoothing_rounds': 266, 'greedy_ratio': 0.4963661075811613}. Best is trial 24 with value: 0.8435701069468268.
# [I 2024-10-22 04:26:51,438] Trial 25 finished with value: 0.8436576971623386 and parameters: {'max_bins': 476, 'max_interaction_bins': 25, 'interactions': 0.7490809537460139, 'outer_bags': 12, 'inner_bags': 3, 'learning_rate': 0.04223605806952838, 'min_samples_leaf': 92, 'max_leaves': 8, 'max_rounds': 17310, 'early_stopping_rounds': 10, 'smoothing_rounds': 286, 'greedy_ratio': 0.35486769998537815}. Best is trial 25 with value: 0.8436576971623386.
# [I 2024-10-22 04:26:57,967] Trial 26 finished with value: 0.8434920883036076 and parameters: {'max_bins': 413, 'max_interaction_bins': 26, 'interactions': 0.7515942875599556, 'outer_bags': 8, 'inner_bags': 6, 'learning_rate': 0.0629250289720814, 'min_samples_leaf': 92, 'max_leaves': 6, 'max_rounds': 16702, 'early_stopping_rounds': 12, 'smoothing_rounds': 274, 'greedy_ratio': 0.41120387866024943}. Best is trial 25 with value: 0.8436576971623386.
# [I 2024-10-22 04:27:02,965] Trial 27 finished with value: 0.843952418956671 and parameters: {'max_bins': 488, 'max_interaction_bins': 16, 'interactions': 0.8667824568015035, 'outer_bags': 11, 'inner_bags': 4, 'learning_rate': 0.03301667286783107, 'min_samples_leaf': 100, 'max_leaves': 8, 'max_rounds': 20092, 'early_stopping_rounds': 18, 'smoothing_rounds': 279, 'greedy_ratio': 0.5572038341032062}. Best is trial 27 with value: 0.843952418956671.
# [I 2024-10-22 04:27:08,426] Trial 28 finished with value: 0.8439057317191577 and parameters: {'max_bins': 492, 'max_interaction_bins': 18, 'interactions': 0.8605628508233459, 'outer_bags': 11, 'inner_bags': 4, 'learning_rate': 0.03209821049295895, 'min_samples_leaf': 99, 'max_leaves': 8, 'max_rounds': 11390, 'early_stopping_rounds': 22, 'smoothing_rounds': 276, 'greedy_ratio': 0.6587748121234924}. Best is trial 27 with value: 0.843952418956671.
# [I 2024-10-22 04:27:14,245] Trial 29 finished with value: 0.8438652419025532 and parameters: {'max_bins': 526, 'max_interaction_bins': 16, 'interactions': 0.8435209185915056, 'outer_bags': 11, 'inner_bags': 4, 'learning_rate': 0.01955066399629401, 'min_samples_leaf': 99, 'max_leaves': 8, 'max_rounds': 11112, 'early_stopping_rounds': 18, 'smoothing_rounds': 310, 'greedy_ratio': 0.6198828665160404}. Best is trial 27 with value: 0.843952418956671.
# [I 2024-10-22 04:27:23,192] Trial 30 finished with value: 0.8435075818558797 and parameters: {'max_bins': 345, 'max_interaction_bins': 16, 'interactions': 0.8474124595447369, 'outer_bags': 5, 'inner_bags': 6, 'learning_rate': 0.01703922825709084, 'min_samples_leaf': 98, 'max_leaves': 8, 'max_rounds': 11378, 'early_stopping_rounds': 20, 'smoothing_rounds': 432, 'greedy_ratio': 0.6129414099326044}. Best is trial 27 with value: 0.843952418956671.
# [I 2024-10-22 04:27:28,652] Trial 31 finished with value: 0.844392642421897 and parameters: {'max_bins': 500, 'max_interaction_bins': 18, 'interactions': 0.8811530587187896, 'outer_bags': 11, 'inner_bags': 4, 'learning_rate': 0.029085502831722468, 'min_samples_leaf': 100, 'max_leaves': 8, 'max_rounds': 10838, 'early_stopping_rounds': 10, 'smoothing_rounds': 304, 'greedy_ratio': 0.6384206745394507}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:27:34,261] Trial 32 finished with value: 0.843885831112017 and parameters: {'max_bins': 551, 'max_interaction_bins': 19, 'interactions': 0.8686216380946818, 'outer_bags': 10, 'inner_bags': 4, 'learning_rate': 0.02614830447938889, 'min_samples_leaf': 100, 'max_leaves': 9, 'max_rounds': 10599, 'early_stopping_rounds': 21, 'smoothing_rounds': 325, 'greedy_ratio': 0.6519491551850644}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:27:40,918] Trial 33 finished with value: 0.8443869270226143 and parameters: {'max_bins': 415, 'max_interaction_bins': 19, 'interactions': 0.9561782342419662, 'outer_bags': 9, 'inner_bags': 4, 'learning_rate': 0.030441481342317885, 'min_samples_leaf': 82, 'max_leaves': 9, 'max_rounds': 9060, 'early_stopping_rounds': 31, 'smoothing_rounds': 352, 'greedy_ratio': 1.0268265904667226}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:27:50,466] Trial 34 finished with value: 0.8443462994855453 and parameters: {'max_bins': 285, 'max_interaction_bins': 19, 'interactions': 0.957070006893586, 'outer_bags': 9, 'inner_bags': 6, 'learning_rate': 0.03318004006193375, 'min_samples_leaf': 84, 'max_leaves': 9, 'max_rounds': 8381, 'early_stopping_rounds': 31, 'smoothing_rounds': 366, 'greedy_ratio': 0.9809887698794157}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:28:27,911] Trial 35 finished with value: 0.8436634125616213 and parameters: {'max_bins': 275, 'max_interaction_bins': 20, 'interactions': 0.9536492302726486, 'outer_bags': 8, 'inner_bags': 6, 'learning_rate': 0.0027573681120767815, 'min_samples_leaf': 84, 'max_leaves': 10, 'max_rounds': 7858, 'early_stopping_rounds': 32, 'smoothing_rounds': 351, 'greedy_ratio': 1.417093495988468}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:28:40,764] Trial 36 finished with value: 0.8441018456608068 and parameters: {'max_bins': 403, 'max_interaction_bins': 34, 'interactions': 0.9557552428809871, 'outer_bags': 6, 'inner_bags': 5, 'learning_rate': 0.008543823594187892, 'min_samples_leaf': 78, 'max_leaves': 9, 'max_rounds': 6707, 'early_stopping_rounds': 30, 'smoothing_rounds': 390, 'greedy_ratio': 1.0218184879362495}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:28:54,927] Trial 37 finished with value: 0.8434131744773681 and parameters: {'max_bins': 392, 'max_interaction_bins': 36, 'interactions': 0.9536321005345677, 'outer_bags': 5, 'inner_bags': 7, 'learning_rate': 0.01021599405471318, 'min_samples_leaf': 77, 'max_leaves': 9, 'max_rounds': 6554, 'early_stopping_rounds': 30, 'smoothing_rounds': 418, 'greedy_ratio': 0.9647318876560838}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:29:03,403] Trial 38 finished with value: 0.8407263170724485 and parameters: {'max_bins': 266, 'max_interaction_bins': 30, 'interactions': 0.21649795328555776, 'outer_bags': 6, 'inner_bags': 5, 'learning_rate': 0.007859356492486796, 'min_samples_leaf': 58, 'max_leaves': 7, 'max_rounds': 9203, 'early_stopping_rounds': 38, 'smoothing_rounds': 382, 'greedy_ratio': 1.4026405420297454}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:29:12,843] Trial 39 finished with value: 0.8436545984518842 and parameters: {'max_bins': 433, 'max_interaction_bins': 44, 'interactions': 0.7865720628576309, 'outer_bags': 9, 'inner_bags': 8, 'learning_rate': 0.02320057680256396, 'min_samples_leaf': 75, 'max_leaves': 9, 'max_rounds': 9839, 'early_stopping_rounds': 29, 'smoothing_rounds': 443, 'greedy_ratio': 1.0413669110986612}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:29:22,318] Trial 40 finished with value: 0.844048616701223 and parameters: {'max_bins': 383, 'max_interaction_bins': 54, 'interactions': 0.9966020452447872, 'outer_bags': 7, 'inner_bags': 5, 'learning_rate': 0.01393606198329797, 'min_samples_leaf': 84, 'max_leaves': 10, 'max_rounds': 7074, 'early_stopping_rounds': 36, 'smoothing_rounds': 410, 'greedy_ratio': 0.7635622754598436}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:29:32,729] Trial 41 finished with value: 0.8442741339620732 and parameters: {'max_bins': 389, 'max_interaction_bins': 63, 'interactions': 0.9957675389641668, 'outer_bags': 8, 'inner_bags': 5, 'learning_rate': 0.006924067285808935, 'min_samples_leaf': 83, 'max_leaves': 10, 'max_rounds': 7184, 'early_stopping_rounds': 36, 'smoothing_rounds': 401, 'greedy_ratio': 0.7987403590134281}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:29:46,682] Trial 42 finished with value: 0.8443510508415752 and parameters: {'max_bins': 286, 'max_interaction_bins': 34, 'interactions': 0.9245531168515042, 'outer_bags': 8, 'inner_bags': 6, 'learning_rate': 0.007952005701109467, 'min_samples_leaf': 80, 'max_leaves': 10, 'max_rounds': 5180, 'early_stopping_rounds': 51, 'smoothing_rounds': 364, 'greedy_ratio': 1.0055688474303135}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:29:58,309] Trial 43 finished with value: 0.8436659603902172 and parameters: {'max_bins': 277, 'max_interaction_bins': 52, 'interactions': 0.9106308855080392, 'outer_bags': 9, 'inner_bags': 6, 'learning_rate': 0.016082941752089346, 'min_samples_leaf': 58, 'max_leaves': 10, 'max_rounds': 5123, 'early_stopping_rounds': 52, 'smoothing_rounds': 354, 'greedy_ratio': 1.3201669490871353}. Best is trial 31 with value: 0.844392642421897.
# [I 2024-10-22 04:30:23,465] Trial 44 finished with value: 0.8444266593766634 and parameters: {'max_bins': 229, 'max_interaction_bins': 62, 'interactions': 0.9061027375288548, 'outer_bags': 8, 'inner_bags': 8, 'learning_rate': 0.00475789208962518, 'min_samples_leaf': 86, 'max_leaves': 10, 'max_rounds': 7793, 'early_stopping_rounds': 41, 'smoothing_rounds': 481, 'greedy_ratio': 0.7950202176763552}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:30:34,819] Trial 45 finished with value: 0.8434190275971152 and parameters: {'max_bins': 144, 'max_interaction_bins': 48, 'interactions': 0.7825060393191492, 'outer_bags': 10, 'inner_bags': 8, 'learning_rate': 0.024686149385108984, 'min_samples_leaf': 93, 'max_leaves': 7, 'max_rounds': 5911, 'early_stopping_rounds': 42, 'smoothing_rounds': 493, 'greedy_ratio': 1.0973575228083603}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:30:50,253] Trial 46 finished with value: 0.8437096866377407 and parameters: {'max_bins': 220, 'max_interaction_bins': 58, 'interactions': 0.9111268004326344, 'outer_bags': 12, 'inner_bags': 10, 'learning_rate': 0.02946648664623828, 'min_samples_leaf': 87, 'max_leaves': 9, 'max_rounds': 8213, 'early_stopping_rounds': 55, 'smoothing_rounds': 369, 'greedy_ratio': 0.8611880285421982}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:30:59,057] Trial 47 finished with value: 0.8435880106072302 and parameters: {'max_bins': 315, 'max_interaction_bins': 38, 'interactions': 0.8059754806424424, 'outer_bags': 7, 'inner_bags': 8, 'learning_rate': 0.03916052996536616, 'min_samples_leaf': 81, 'max_leaves': 10, 'max_rounds': 9242, 'early_stopping_rounds': 50, 'smoothing_rounds': 466, 'greedy_ratio': 1.755985184890712}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:31:04,206] Trial 48 finished with value: 0.8407291403419737 and parameters: {'max_bins': 146, 'max_interaction_bins': 43, 'interactions': 0.49930929157915654, 'outer_bags': 3, 'inner_bags': 7, 'learning_rate': 0.03644006759755043, 'min_samples_leaf': 74, 'max_leaves': 9, 'max_rounds': 10165, 'early_stopping_rounds': 59, 'smoothing_rounds': 451, 'greedy_ratio': 0.06926660940895069}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:31:19,769] Trial 49 finished with value: 0.8438989145561578 and parameters: {'max_bins': 175, 'max_interaction_bins': 24, 'interactions': 0.9417060516876757, 'outer_bags': 9, 'inner_bags': 9, 'learning_rate': 0.013222156959064053, 'min_samples_leaf': 88, 'max_leaves': 10, 'max_rounds': 12349, 'early_stopping_rounds': 41, 'smoothing_rounds': 329, 'greedy_ratio': 1.5492876214539244}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:31:54,393] Trial 50 finished with value: 0.8437356469453255 and parameters: {'max_bins': 448, 'max_interaction_bins': 64, 'interactions': 0.877617862489606, 'outer_bags': 12, 'inner_bags': 9, 'learning_rate': 0.004915825711973496, 'min_samples_leaf': 25, 'max_leaves': 7, 'max_rounds': 7577, 'early_stopping_rounds': 15, 'smoothing_rounds': 338, 'greedy_ratio': 0.26462676009973307}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:32:07,138] Trial 51 finished with value: 0.8442339195863979 and parameters: {'max_bins': 368, 'max_interaction_bins': 64, 'interactions': 0.9751550241301101, 'outer_bags': 8, 'inner_bags': 5, 'learning_rate': 0.005831111841602728, 'min_samples_leaf': 82, 'max_leaves': 10, 'max_rounds': 5811, 'early_stopping_rounds': 35, 'smoothing_rounds': 396, 'greedy_ratio': 0.849364157735472}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:32:16,868] Trial 52 finished with value: 0.8376503993549174 and parameters: {'max_bins': 317, 'max_interaction_bins': 60, 'interactions': 0.06503024299461868, 'outer_bags': 6, 'inner_bags': 6, 'learning_rate': 0.019777152482214504, 'min_samples_leaf': 68, 'max_leaves': 10, 'max_rounds': 8750, 'early_stopping_rounds': 50, 'smoothing_rounds': 363, 'greedy_ratio': 0.7181502774339188}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:32:30,422] Trial 53 finished with value: 0.8440424881405465 and parameters: {'max_bins': 250, 'max_interaction_bins': 62, 'interactions': 0.8960051601650143, 'outer_bags': 8, 'inner_bags': 5, 'learning_rate': 0.012197941827577845, 'min_samples_leaf': 94, 'max_leaves': 9, 'max_rounds': 7341, 'early_stopping_rounds': 26, 'smoothing_rounds': 495, 'greedy_ratio': 0.9152485549634566}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:32:53,891] Trial 54 finished with value: 0.8440471706363442 and parameters: {'max_bins': 344, 'max_interaction_bins': 58, 'interactions': 0.9985401739530096, 'outer_bags': 10, 'inner_bags': 3, 'learning_rate': 0.002007078963029858, 'min_samples_leaf': 85, 'max_leaves': 8, 'max_rounds': 6050, 'early_stopping_rounds': 43, 'smoothing_rounds': 373, 'greedy_ratio': 1.299480908185457}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:33:16,247] Trial 55 finished with value: 0.8433609095610367 and parameters: {'max_bins': 78, 'max_interaction_bins': 55, 'interactions': 0.8182582902977478, 'outer_bags': 9, 'inner_bags': 7, 'learning_rate': 0.01640493101636019, 'min_samples_leaf': 80, 'max_leaves': 10, 'max_rounds': 9466, 'early_stopping_rounds': 37, 'smoothing_rounds': 406, 'greedy_ratio': 0.4215025872954927}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:33:32,433] Trial 56 finished with value: 0.8441466736720475 and parameters: {'max_bins': 300, 'max_interaction_bins': 61, 'interactions': 0.9354325409454394, 'outer_bags': 8, 'inner_bags': 6, 'learning_rate': 0.07432619024161753, 'min_samples_leaf': 95, 'max_leaves': 9, 'max_rounds': 8622, 'early_stopping_rounds': 96, 'smoothing_rounds': 421, 'greedy_ratio': 0.7771025506287478}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:33:54,658] Trial 57 finished with value: 0.8406969137532475 and parameters: {'max_bins': 201, 'max_interaction_bins': 56, 'interactions': 0.320583871703897, 'outer_bags': 13, 'inner_bags': 5, 'learning_rate': 0.023281533689189476, 'min_samples_leaf': 74, 'max_leaves': 10, 'max_rounds': 5037, 'early_stopping_rounds': 56, 'smoothing_rounds': 303, 'greedy_ratio': 1.0582371548181155}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:34:05,428] Trial 58 finished with value: 0.8439062826010162 and parameters: {'max_bins': 453, 'max_interaction_bins': 50, 'interactions': 0.8910163870142164, 'outer_bags': 10, 'inner_bags': 3, 'learning_rate': 0.02900678891645574, 'min_samples_leaf': 89, 'max_leaves': 9, 'max_rounds': 14442, 'early_stopping_rounds': 33, 'smoothing_rounds': 248, 'greedy_ratio': 1.1619471985136238}. Best is trial 44 with value: 0.8444266593766634.
# [I 2024-10-22 04:34:17,084] Trial 59 finished with value: 0.8444544100502887 and parameters: {'max_bins': 235, 'max_interaction_bins': 21, 'interactions': 0.9692750284240337, 'outer_bags': 5, 'inner_bags': 4, 'learning_rate': 0.056066294369288755, 'min_samples_leaf': 77, 'max_leaves': 10, 'max_rounds': 8085, 'early_stopping_rounds': 69, 'smoothing_rounds': 469, 'greedy_ratio': 0.5160859612606057}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:34:25,098] Trial 60 finished with value: 0.843223739978254 and parameters: {'max_bins': 240, 'max_interaction_bins': 21, 'interactions': 0.8208413050524114, 'outer_bags': 1, 'inner_bags': 4, 'learning_rate': 0.057208186248539974, 'min_samples_leaf': 62, 'max_leaves': 8, 'max_rounds': 12192, 'early_stopping_rounds': 80, 'smoothing_rounds': 454, 'greedy_ratio': 0.2709510754446489}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:34:31,901] Trial 61 finished with value: 0.8443560087783024 and parameters: {'max_bins': 116, 'max_interaction_bins': 18, 'interactions': 0.9614087739051315, 'outer_bags': 7, 'inner_bags': 4, 'learning_rate': 0.06876776539222071, 'min_samples_leaf': 79, 'max_leaves': 10, 'max_rounds': 7986, 'early_stopping_rounds': 66, 'smoothing_rounds': 479, 'greedy_ratio': 0.5173611779809195}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:34:37,601] Trial 62 finished with value: 0.8443626882208376 and parameters: {'max_bins': 122, 'max_interaction_bins': 18, 'interactions': 0.962625264824085, 'outer_bags': 5, 'inner_bags': 4, 'learning_rate': 0.06815324517062098, 'min_samples_leaf': 77, 'max_leaves': 10, 'max_rounds': 8202, 'early_stopping_rounds': 73, 'smoothing_rounds': 479, 'greedy_ratio': 0.39059582984402713}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:34:42,625] Trial 63 finished with value: 0.8432511463507176 and parameters: {'max_bins': 108, 'max_interaction_bins': 23, 'interactions': 0.9246153590615271, 'outer_bags': 4, 'inner_bags': 4, 'learning_rate': 0.07070986634493746, 'min_samples_leaf': 47, 'max_leaves': 10, 'max_rounds': 10584, 'early_stopping_rounds': 71, 'smoothing_rounds': 481, 'greedy_ratio': 0.5130802634428584}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:34:47,947] Trial 64 finished with value: 0.8438036808548584 and parameters: {'max_bins': 179, 'max_interaction_bins': 17, 'interactions': 0.8873500349877236, 'outer_bags': 7, 'inner_bags': 3, 'learning_rate': 0.06650398475960004, 'min_samples_leaf': 72, 'max_leaves': 10, 'max_rounds': 6423, 'early_stopping_rounds': 73, 'smoothing_rounds': 475, 'greedy_ratio': 0.12404217795026934}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:34:52,824] Trial 65 finished with value: 0.8438816306378454 and parameters: {'max_bins': 117, 'max_interaction_bins': 20, 'interactions': 0.972498561593977, 'outer_bags': 5, 'inner_bags': 3, 'learning_rate': 0.07783679820406667, 'min_samples_leaf': 78, 'max_leaves': 10, 'max_rounds': 8016, 'early_stopping_rounds': 68, 'smoothing_rounds': 433, 'greedy_ratio': 0.4475289245378322}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:34:57,951] Trial 66 finished with value: 0.8435189437942124 and parameters: {'max_bins': 187, 'max_interaction_bins': 18, 'interactions': 0.8498475005584506, 'outer_bags': 3, 'inner_bags': 4, 'learning_rate': 0.05515511231991262, 'min_samples_leaf': 67, 'max_leaves': 9, 'max_rounds': 9228, 'early_stopping_rounds': 80, 'smoothing_rounds': 500, 'greedy_ratio': 0.3000348117087389}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:35:01,708] Trial 67 finished with value: 0.8434792803003959 and parameters: {'max_bins': 68, 'max_interaction_bins': 29, 'interactions': 0.9259736076677666, 'outer_bags': 4, 'inner_bags': 2, 'learning_rate': 0.06097417945466724, 'min_samples_leaf': 76, 'max_leaves': 10, 'max_rounds': 7603, 'early_stopping_rounds': 76, 'smoothing_rounds': 473, 'greedy_ratio': 0.008463217902187514}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:35:08,762] Trial 68 finished with value: 0.8437598168868702 and parameters: {'max_bins': 233, 'max_interaction_bins': 24, 'interactions': 0.7766414590299467, 'outer_bags': 6, 'inner_bags': 4, 'learning_rate': 0.06673928204497775, 'min_samples_leaf': 80, 'max_leaves': 9, 'max_rounds': 5727, 'early_stopping_rounds': 67, 'smoothing_rounds': 444, 'greedy_ratio': 0.5524742082449701}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:35:14,871] Trial 69 finished with value: 0.8443991152837351 and parameters: {'max_bins': 138, 'max_interaction_bins': 21, 'interactions': 0.9655681217390235, 'outer_bags': 5, 'inner_bags': 4, 'learning_rate': 0.08331211483485262, 'min_samples_leaf': 63, 'max_leaves': 10, 'max_rounds': 10050, 'early_stopping_rounds': 64, 'smoothing_rounds': 483, 'greedy_ratio': 0.1838948418237467}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:35:18,047] Trial 70 finished with value: 0.8425192309413813 and parameters: {'max_bins': 133, 'max_interaction_bins': 21, 'interactions': 0.9709472420322752, 'outer_bags': 2, 'inner_bags': 2, 'learning_rate': 0.08714697317607491, 'min_samples_leaf': 63, 'max_leaves': 9, 'max_rounds': 10266, 'early_stopping_rounds': 64, 'smoothing_rounds': 484, 'greedy_ratio': 0.35971587087144197}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:35:25,374] Trial 71 finished with value: 0.8439774152210036 and parameters: {'max_bins': 161, 'max_interaction_bins': 18, 'interactions': 0.9361860028992176, 'outer_bags': 7, 'inner_bags': 4, 'learning_rate': 0.0966476893219875, 'min_samples_leaf': 70, 'max_leaves': 10, 'max_rounds': 9737, 'early_stopping_rounds': 62, 'smoothing_rounds': 463, 'greedy_ratio': 0.7004191593867055}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:35:30,095] Trial 72 finished with value: 0.8432424699614451 and parameters: {'max_bins': 119, 'max_interaction_bins': 27, 'interactions': 0.8825468368003603, 'outer_bags': 5, 'inner_bags': 3, 'learning_rate': 0.08492759119993504, 'min_samples_leaf': 58, 'max_leaves': 10, 'max_rounds': 8752, 'early_stopping_rounds': 57, 'smoothing_rounds': 486, 'greedy_ratio': 0.163850028017344}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:35:37,878] Trial 73 finished with value: 0.8418753877691834 and parameters: {'max_bins': 94, 'max_interaction_bins': 23, 'interactions': 0.8373393228708592, 'outer_bags': 6, 'inner_bags': 4, 'learning_rate': 0.08262524655068873, 'min_samples_leaf': 73, 'max_leaves': 2, 'max_rounds': 11860, 'early_stopping_rounds': 73, 'smoothing_rounds': 461, 'greedy_ratio': 0.1951859377147209}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:35:41,620] Trial 74 finished with value: 0.8431852471083867 and parameters: {'max_bins': 201, 'max_interaction_bins': 20, 'interactions': 0.9639357218662362, 'outer_bags': 3, 'inner_bags': 3, 'learning_rate': 0.09122226041473326, 'min_samples_leaf': 90, 'max_leaves': 10, 'max_rounds': 10647, 'early_stopping_rounds': 65, 'smoothing_rounds': 431, 'greedy_ratio': 0.598831935921553}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:35:47,064] Trial 75 finished with value: 0.8440466197544857 and parameters: {'max_bins': 517, 'max_interaction_bins': 17, 'interactions': 0.9117080958274169, 'outer_bags': 5, 'inner_bags': 5, 'learning_rate': 0.05292653975253506, 'min_samples_leaf': 86, 'max_leaves': 9, 'max_rounds': 6835, 'early_stopping_rounds': 84, 'smoothing_rounds': 293, 'greedy_ratio': 0.48157887975819963}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:35:52,472] Trial 76 finished with value: 0.8434575204669825 and parameters: {'max_bins': 572, 'max_interaction_bins': 32, 'interactions': 0.8619286803358026, 'outer_bags': 4, 'inner_bags': 4, 'learning_rate': 0.07018946647206256, 'min_samples_leaf': 53, 'max_leaves': 10, 'max_rounds': 7906, 'early_stopping_rounds': 60, 'smoothing_rounds': 442, 'greedy_ratio': 0.327118065692783}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:35:58,943] Trial 77 finished with value: 0.844214845302045 and parameters: {'max_bins': 257, 'max_interaction_bins': 21, 'interactions': 0.9478227038795828, 'outer_bags': 7, 'inner_bags': 4, 'learning_rate': 0.04609934643342459, 'min_samples_leaf': 78, 'max_leaves': 9, 'max_rounds': 8991, 'early_stopping_rounds': 70, 'smoothing_rounds': 228, 'greedy_ratio': 0.8971111170198067}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:36:14,847] Trial 78 finished with value: 0.8440133602622749 and parameters: {'max_bins': 215, 'max_interaction_bins': 25, 'interactions': 0.9797368579888623, 'outer_bags': 6, 'inner_bags': 5, 'learning_rate': 0.09347392203500308, 'min_samples_leaf': 96, 'max_leaves': 10, 'max_rounds': 9963, 'early_stopping_rounds': 53, 'smoothing_rounds': 470, 'greedy_ratio': 0.39701829640409614}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:36:23,748] Trial 79 finished with value: 0.8422462689804623 and parameters: {'max_bins': 177, 'max_interaction_bins': 17, 'interactions': 0.5086455459492419, 'outer_bags': 8, 'inner_bags': 3, 'learning_rate': 0.07827857168765036, 'min_samples_leaf': 69, 'max_leaves': 10, 'max_rounds': 13172, 'early_stopping_rounds': 48, 'smoothing_rounds': 490, 'greedy_ratio': 0.7304664333971429}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:36:37,618] Trial 80 finished with value: 0.8437072076693772 and parameters: {'max_bins': 668, 'max_interaction_bins': 22, 'interactions': 0.7174864700354682, 'outer_bags': 4, 'inner_bags': 5, 'learning_rate': 0.06270172908065973, 'min_samples_leaf': 91, 'max_leaves': 8, 'max_rounds': 6444, 'early_stopping_rounds': 74, 'smoothing_rounds': 421, 'greedy_ratio': 0.5680163220881553}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:36:49,603] Trial 81 finished with value: 0.8443263988784045 and parameters: {'max_bins': 284, 'max_interaction_bins': 19, 'interactions': 0.9606343179555838, 'outer_bags': 9, 'inner_bags': 6, 'learning_rate': 0.03519799613229639, 'min_samples_leaf': 83, 'max_leaves': 9, 'max_rounds': 8280, 'early_stopping_rounds': 65, 'smoothing_rounds': 319, 'greedy_ratio': 0.9835264276788607}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:36:56,835] Trial 82 finished with value: 0.8443445779797372 and parameters: {'max_bins': 360, 'max_interaction_bins': 19, 'interactions': 0.9162676842911052, 'outer_bags': 11, 'inner_bags': 4, 'learning_rate': 0.07363068604299844, 'min_samples_leaf': 65, 'max_leaves': 9, 'max_rounds': 8373, 'early_stopping_rounds': 66, 'smoothing_rounds': 345, 'greedy_ratio': 0.6665095138010649}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:37:08,605] Trial 83 finished with value: 0.8441639575903601 and parameters: {'max_bins': 873, 'max_interaction_bins': 16, 'interactions': 0.9943847494810215, 'outer_bags': 10, 'inner_bags': 7, 'learning_rate': 0.0597117213882799, 'min_samples_leaf': 86, 'max_leaves': 10, 'max_rounds': 11125, 'early_stopping_rounds': 44, 'smoothing_rounds': 380, 'greedy_ratio': 1.1225874797959776}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:37:14,879] Trial 84 finished with value: 0.8440926183896759 and parameters: {'max_bins': 154, 'max_interaction_bins': 35, 'interactions': 0.9443668258780609, 'outer_bags': 9, 'inner_bags': 4, 'learning_rate': 0.044510084212788174, 'min_samples_leaf': 79, 'max_leaves': 9, 'max_rounds': 7400, 'early_stopping_rounds': 58, 'smoothing_rounds': 334, 'greedy_ratio': 1.23476006051407}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:37:23,778] Trial 85 finished with value: 0.843818623525272 and parameters: {'max_bins': 304, 'max_interaction_bins': 18, 'interactions': 0.8942467505343539, 'outer_bags': 7, 'inner_bags': 8, 'learning_rate': 0.031155134337751196, 'min_samples_leaf': 76, 'max_leaves': 10, 'max_rounds': 5594, 'early_stopping_rounds': 27, 'smoothing_rounds': 363, 'greedy_ratio': 0.8021326425613717}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:37:38,453] Trial 86 finished with value: 0.8441817923905311 and parameters: {'max_bins': 336, 'max_interaction_bins': 38, 'interactions': 0.8755411242657495, 'outer_bags': 8, 'inner_bags': 5, 'learning_rate': 0.038281302103601436, 'min_samples_leaf': 82, 'max_leaves': 8, 'max_rounds': 6915, 'early_stopping_rounds': 39, 'smoothing_rounds': 453, 'greedy_ratio': 1.8266189473254202}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:37:57,101] Trial 87 finished with value: 0.8431846962265281 and parameters: {'max_bins': 103, 'max_interaction_bins': 41, 'interactions': 0.9687033648827781, 'outer_bags': 11, 'inner_bags': 10, 'learning_rate': 0.09971423269163983, 'min_samples_leaf': 9, 'max_leaves': 10, 'max_rounds': 9581, 'early_stopping_rounds': 62, 'smoothing_rounds': 355, 'greedy_ratio': 0.9433871979425734}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:38:16,532] Trial 88 finished with value: 0.8437541703478199 and parameters: {'max_bins': 227, 'max_interaction_bins': 20, 'interactions': 0.9296601957727685, 'outer_bags': 7, 'inner_bags': 9, 'learning_rate': 0.05313843015687318, 'min_samples_leaf': 88, 'max_leaves': 9, 'max_rounds': 8889, 'early_stopping_rounds': 71, 'smoothing_rounds': 480, 'greedy_ratio': 0.4801915856026009}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:38:24,450] Trial 89 finished with value: 0.8416462897762524 and parameters: {'max_bins': 287, 'max_interaction_bins': 45, 'interactions': 0.47181616410151817, 'outer_bags': 5, 'inner_bags': 6, 'learning_rate': 0.06955672439367919, 'min_samples_leaf': 38, 'max_leaves': 6, 'max_rounds': 7838, 'early_stopping_rounds': 15, 'smoothing_rounds': 314, 'greedy_ratio': 0.22479344968935233}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:39:10,195] Trial 90 finished with value: 0.8443340423641922 and parameters: {'max_bins': 163, 'max_interaction_bins': 25, 'interactions': 0.8315127921300809, 'outer_bags': 13, 'inner_bags': 5, 'learning_rate': 0.009901789630413011, 'min_samples_leaf': 96, 'max_leaves': 10, 'max_rounds': 6304, 'early_stopping_rounds': 79, 'smoothing_rounds': 266, 'greedy_ratio': 0.6299058153060398}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:39:21,252] Trial 91 finished with value: 0.8443266054591014 and parameters: {'max_bins': 362, 'max_interaction_bins': 22, 'interactions': 0.9130540157947659, 'outer_bags': 11, 'inner_bags': 4, 'learning_rate': 0.07604527078283795, 'min_samples_leaf': 65, 'max_leaves': 9, 'max_rounds': 8461, 'early_stopping_rounds': 66, 'smoothing_rounds': 345, 'greedy_ratio': 0.6735308691685634}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:39:32,106] Trial 92 finished with value: 0.8441605834389763 and parameters: {'max_bins': 410, 'max_interaction_bins': 19, 'interactions': 0.9083366701037717, 'outer_bags': 12, 'inner_bags': 4, 'learning_rate': 0.07355108326333137, 'min_samples_leaf': 56, 'max_leaves': 9, 'max_rounds': 8325, 'early_stopping_rounds': 69, 'smoothing_rounds': 392, 'greedy_ratio': 0.8105083524387238}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:39:40,237] Trial 93 finished with value: 0.8440616312851317 and parameters: {'max_bins': 434, 'max_interaction_bins': 19, 'interactions': 0.9563848901463845, 'outer_bags': 10, 'inner_bags': 3, 'learning_rate': 0.08052684727527093, 'min_samples_leaf': 61, 'max_leaves': 7, 'max_rounds': 7308, 'early_stopping_rounds': 60, 'smoothing_rounds': 499, 'greedy_ratio': 0.5237056164580979}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:39:47,245] Trial 94 finished with value: 0.8443960165732807 and parameters: {'max_bins': 370, 'max_interaction_bins': 17, 'interactions': 0.9999053240358704, 'outer_bags': 9, 'inner_bags': 4, 'learning_rate': 0.06509864789217787, 'min_samples_leaf': 72, 'max_leaves': 10, 'max_rounds': 9454, 'early_stopping_rounds': 75, 'smoothing_rounds': 304, 'greedy_ratio': 0.868623261812729}. Best is trial 59 with value: 0.8444544100502887.
# [I 2024-10-22 04:39:55,499] Trial 95 finished with value: 0.8445228571212153 and parameters: {'max_bins': 471, 'max_interaction_bins': 16, 'interactions': 0.9874530153492641, 'outer_bags': 9, 'inner_bags': 5, 'learning_rate': 0.06484304370718583, 'min_samples_leaf': 74, 'max_leaves': 10, 'max_rounds': 10933, 'early_stopping_rounds': 83, 'smoothing_rounds': 264, 'greedy_ratio': 0.9967306517111342}. Best is trial 95 with value: 0.8445228571212153.
# [I 2024-10-22 04:40:03,102] Trial 96 finished with value: 0.8445020613310545 and parameters: {'max_bins': 463, 'max_interaction_bins': 17, 'interactions': 0.9971919563415365, 'outer_bags': 8, 'inner_bags': 5, 'learning_rate': 0.05804097480255894, 'min_samples_leaf': 73, 'max_leaves': 10, 'max_rounds': 10697, 'early_stopping_rounds': 77, 'smoothing_rounds': 262, 'greedy_ratio': 1.0326572047459535}. Best is trial 95 with value: 0.8445228571212153.
# [I 2024-10-22 04:40:09,793] Trial 97 finished with value: 0.8444441498756727 and parameters: {'max_bins': 464, 'max_interaction_bins': 16, 'interactions': 0.9796428396860243, 'outer_bags': 6, 'inner_bags': 5, 'learning_rate': 0.06456938393657062, 'min_samples_leaf': 72, 'max_leaves': 10, 'max_rounds': 11651, 'early_stopping_rounds': 84, 'smoothing_rounds': 251, 'greedy_ratio': 0.8766100977965291}. Best is trial 95 with value: 0.8445228571212153.
# [I 2024-10-22 04:40:16,934] Trial 98 finished with value: 0.8445000643843172 and parameters: {'max_bins': 514, 'max_interaction_bins': 16, 'interactions': 0.9985962939998202, 'outer_bags': 6, 'inner_bags': 5, 'learning_rate': 0.06423695907306069, 'min_samples_leaf': 72, 'max_leaves': 10, 'max_rounds': 11732, 'early_stopping_rounds': 87, 'smoothing_rounds': 260, 'greedy_ratio': 0.8823898654670876}. Best is trial 95 with value: 0.8445228571212153.
# [I 2024-10-22 04:40:24,553] Trial 99 finished with value: 0.8444408445845215 and parameters: {'max_bins': 474, 'max_interaction_bins': 16, 'interactions': 0.996180619661343, 'outer_bags': 6, 'inner_bags': 5, 'learning_rate': 0.059989783246088974, 'min_samples_leaf': 68, 'max_leaves': 10, 'max_rounds': 11664, 'early_stopping_rounds': 88, 'smoothing_rounds': 262, 'greedy_ratio': 0.8524758673948399}. Best is trial 95 with value: 0.8445228571212153.

# %%
# Print the best hyperparameters and best ROC-AUC score
print("Best hyperparameters:", study_ebm.best_params)
print("Best ROC-AUC score:", study_ebm.best_value)
# Out:
# Best hyperparameters: {'max_bins': 471, 'max_interaction_bins': 16, 'interactions': 0.9874530153492641, 'outer_bags': 9, 'inner_bags': 5, 'learning_rate': 0.06484304370718583, 'min_samples_leaf': 74, 'max_leaves': 10, 'max_rounds': 10933, 'early_stopping_rounds': 83, 'smoothing_rounds': 264, 'greedy_ratio': 0.9967306517111342}
# Best ROC-AUC score: 0.8445228571212153

# %%
# Save the best configurations to a JSON file
config_file_path = Path("ebm_apsiii_best_configs.json")

# Load the saved configuration (if it exists)
if config_file_path.exists():
    with open(config_file_path, "r") as config_file:
        saved_configs = json.load(config_file)

    # Compare the new best value with the saved one
    if study_ebm.best_value > saved_configs["best_value"]:
        print("New best value found. Replacing saved configuration.")
        saved_configs["best_params"] = study_ebm.best_params
        saved_configs["best_value"] = study_ebm.best_value

        # Update the saved configuration file
        with open(config_file_path, "w") as config_file:
            json.dump(saved_configs, config_file)
else:
    # If no saved configuration exists, create a new one
    saved_configs = {
        "best_params": study_ebm.best_params,
        "best_value": study_ebm.best_value
    }

    with open(config_file_path, "w") as config_file:
        json.dump(saved_configs, config_file)

# %% [markdown]
# ## Random Forest Optuna Optimization

# %%
def objective_rf(trial: optuna.Trial):
    try:
        # Split the data into training and validation sets (ensure stratification)
        x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(
            X_balanced, y_balanced, test_size=0.2, random_state=42, stratify=y_balanced
        )

        # Initialize StandardScaler
        scaler = StandardScaler()

        # Fit the scaler on the training data and transform both the training and validation sets
        x_train_split = scaler.fit_transform(x_train_split)
        x_valid_split = scaler.transform(x_valid_split)

        # Suggest hyperparameters for RandomForestClassifier, but ensure ranges are sensible
        n_estimators = trial.suggest_int('n_estimators', 100, 300)  # Limit range based on reasonable number of trees
        criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
        max_depth = trial.suggest_int('max_depth', 10, 30)  # Limit max_depth to prevent overfitting
        min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 5)
        min_weight_fraction_leaf = trial.suggest_float('min_weight_fraction_leaf', 0.0, 0.2)  # Tighten the range
        max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])  # Avoid 'auto'

        # Handle None for max_leaf_nodes by using suggest_categorical
        max_leaf_nodes = trial.suggest_categorical('max_leaf_nodes', [None, 20, 50, 100])

        min_impurity_decrease = trial.suggest_float('min_impurity_decrease', 0.0, 0.1)
        bootstrap = trial.suggest_categorical('bootstrap', [True, False])

        # Handle oob_score: If bootstrap is False, oob_score must be False
        if bootstrap:
            oob_score = trial.suggest_categorical('oob_score', [True, False])
            max_samples = trial.suggest_categorical('max_samples', [None, 0.5, 0.75, 1.0])
        else:
            oob_score = False  # Set to False when bootstrap is False
            max_samples = None  # Force max_samples to be None if bootstrap is False

        class_weight = trial.suggest_categorical('class_weight', [None, 'balanced', 'balanced_subsample'])
        ccp_alpha = trial.suggest_float('ccp_alpha', 0.0, 0.05)  # Tighten range

        # Train the model with the sampled hyperparameters
        _, results_rf = train_random_forest_model(
            X_train=x_train_split,
            y_train=y_train_split,
            X_test=x_valid_split,
            n_estimators=n_estimators,
            criterion=criterion,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            min_weight_fraction_leaf=min_weight_fraction_leaf,
            max_features=max_features,
            max_leaf_nodes=max_leaf_nodes,
            min_impurity_decrease=min_impurity_decrease,
            bootstrap=bootstrap,
            oob_score=oob_score,
            class_weight=class_weight,
            ccp_alpha=ccp_alpha,
            max_samples=max_samples,
            random_state=42,  # Fix random state for reproducibility
            verbose=False
        )

        # Calculate the ROC-AUC score on validation data
        roc_auc = roc_auc_score(y_valid_split, results_rf['y_pred_prob'])

        # Maximize ROC-AUC
        return roc_auc

    except Exception as e:
        # Print the error for debugging purposes (optional)
        print(f"Trial failed with error: {e}")
        
        # Return 0.0 ROC-AUC to indicate failure
        return 0.0

# %%
# Create an Optuna study with SQLite storage and TPE pruner
study_name = "Optuna_hyperparameter_optimization"
storage_name = "sqlite:///{}.db".format(study_name)

study_rf = optuna.create_study(
    study_name="Case 11: Random_Forest_APSIII",
    direction="maximize",  # Maximize ROC-AUC
    storage=storage_name,
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5),  
)

# Perform a trial with default values first
default_params = {
    'n_estimators': 100,
    'criterion': 'gini',
    'max_depth': 10,
    'min_samples_split': 2,
    'min_samples_leaf': 1,
    'min_weight_fraction_leaf': 0.0,
    'max_features': 'sqrt',
    'max_leaf_nodes': 25,
    'min_impurity_decrease': 0.0,
    'bootstrap': True,
    'oob_score': False,
    'class_weight': None,
    'ccp_alpha': 0.0,
    'max_samples': 0.5
}
study_rf.enqueue_trial(default_params)

# Define the number of trials (hyperparameter combinations) to search
num_trials = 100

# Perform hyperparameter optimization
study_rf.optimize(objective_rf, n_trials=num_trials, n_jobs=1)
# Out:
# [I 2024-10-22 04:40:24,845] A new study created in RDB with name: Case 11: Random_Forest_APSIII
# [I 2024-10-22 04:40:25,070] Trial 0 finished with value: 0.0 and parameters: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.0.
# Trial failed with error: '25' not in (None, 20, 50, 100).
# [I 2024-10-22 04:40:29,225] Trial 1 finished with value: 0.6662125219578066 and parameters: {'n_estimators': 134, 'criterion': 'entropy', 'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.0800334448007944, 'max_features': None, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.053786961459400706, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.026094645858733657}. Best is trial 1 with value: 0.6662125219578066.
# [I 2024-10-22 04:40:32,355] Trial 2 finished with value: 0.7294746928317186 and parameters: {'n_estimators': 222, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.1707358035470269, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0393009026243443, 'bootstrap': True, 'oob_score': True, 'max_samples': None, 'class_weight': 'balanced', 'ccp_alpha': 0.015977087019342997}. Best is trial 2 with value: 0.7294746928317186.
# [I 2024-10-22 04:40:35,186] Trial 3 finished with value: 0.7180749158011509 and parameters: {'n_estimators': 155, 'criterion': 'entropy', 'max_depth': 29, 'min_samples_split': 3, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.05691367272962336, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.06937616851000536, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.00524240187097183}. Best is trial 2 with value: 0.7294746928317186.
# [I 2024-10-22 04:40:37,514] Trial 4 finished with value: 0.5 and parameters: {'n_estimators': 144, 'criterion': 'gini', 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.024525684263470994, 'max_features': None, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0991010088920386, 'bootstrap': True, 'oob_score': False, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.04540509130595376}. Best is trial 2 with value: 0.7294746928317186.
# [I 2024-10-22 04:40:38,886] Trial 5 finished with value: 0.5 and parameters: {'n_estimators': 141, 'criterion': 'gini', 'max_depth': 26, 'min_samples_split': 2, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.055319463887598765, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.06726086189865074, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.017695154792355134}. Best is trial 2 with value: 0.7294746928317186.
# [I 2024-10-22 04:40:44,526] Trial 6 finished with value: 0.7604083618357312 and parameters: {'n_estimators': 294, 'criterion': 'gini', 'max_depth': 17, 'min_samples_split': 2, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.07228770785095398, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.025865862820655075, 'bootstrap': True, 'oob_score': True, 'max_samples': 0.5, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.01664042881077233}. Best is trial 6 with value: 0.7604083618357312.
# [I 2024-10-22 04:40:57,736] Trial 7 finished with value: 0.6662125219578066 and parameters: {'n_estimators': 279, 'criterion': 'gini', 'max_depth': 21, 'min_samples_split': 7, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.028410785131896234, 'max_features': None, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.00529489211931995, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.025887818426498295}. Best is trial 6 with value: 0.7604083618357312.
# [I 2024-10-22 04:40:59,816] Trial 8 finished with value: 0.5 and parameters: {'n_estimators': 134, 'criterion': 'gini', 'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.17191501276667406, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0
 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0003471111778725485, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': None, 'ccp_alpha': 0.0014470626610814262}. Best is trial 17 with value: 0.7864790179429108.
# [I 2024-10-22 04:41:58,878] Trial 18 finished with value: 0.5 and parameters: {'n_estimators': 222, 'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.09643819898949231, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.039801498264260535, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': None, 'ccp_alpha': 0.0007508466748930645}. Best is trial 17 with value: 0.7864790179429108.
# [I 2024-10-22 04:42:02,887] Trial 19 finished with value: 0.7670335769378818 and parameters: {'n_estimators': 192, 'criterion': 'entropy', 'max_depth': 24, 'min_samples_split': 9, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.09369927707612222, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.018395064992362885, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': 'balanced', 'ccp_alpha': 0.033398843121256676}. Best is trial 17 with value: 0.7864790179429108.
# [I 2024-10-22 04:42:06,382] Trial 20 finished with value: 0.5 and parameters: {'n_estimators': 243, 'criterion': 'entropy', 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.1524537956206375, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.09204983904909143, 'bootstrap': True, 'oob_score': False, 'max_samples': None, 'class_weight': None, 'ccp_alpha': 0.020898472670580467}. Best is trial 17 with value: 0.7864790179429108.
# [I 2024-10-22 04:42:13,273] Trial 21 finished with value: 0.7781674157512273 and parameters: {'n_estimators': 265, 'criterion': 'entropy', 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.11330762965502476, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0002500371870136136, 'bootstrap': True, 'oob_score': True, 'max_samples': 0.75, 'class_weight': None, 'ccp_alpha': 0.0077468287490895385}. Best is trial 17 with value: 0.7864790179429108.
# [I 2024-10-22 04:42:18,453] Trial 22 finished with value: 0.7747116649922153 and parameters: {'n_estimators': 273, 'criterion': 'entropy', 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.10649499092758748, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.010180865244853876, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': None, 'ccp_alpha': 0.00017987279143696216}. Best is trial 17 with value: 0.7864790179429108.
# [I 2024-10-22 04:42:24,033] Trial 23 finished with value: 0.7746212859372945 and parameters: {'n_estimators': 232, 'criterion': 'entropy', 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.10849542374746227, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0032259045701166743, 'bootstrap': True, 'oob_score': True, 'max_samples': 0.5, 'class_weight': None, 'ccp_alpha': 0.010960807907383414}. Best is trial 17 with value: 0.7864790179429108.
# [I 2024-10-22 04:42:29,026] Trial 24 finished with value: 0.7586243309367677 and parameters: {'n_estimators': 265, 'criterion': 'entropy', 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.1462556945799839, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.016030832285043393, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': None, 'ccp_alpha': 0.006061249635077549}. Best is trial 17 with value: 0.7864790179429108.
# [I 2024-10-22 04:42:33,683] Trial 25 finished with value: 0.7203836616703977 and parameters: {'n_estimators': 238, 'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.08096045515128782, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.033098571396758494, 'bootstrap': True, 'oob_score': True, 'max_samples': 0.75, 'class_weight': None, 'ccp_alpha': 0.00525015191133601}. Best is trial 17 with value: 0.7864790179429108.
# [I 2024-10-22 04:42:39,605] Trial 26 finished with value: 0.7785984119453222 and parameters: {'n_estimators': 203, 'criterion': 'entropy', 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0
criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.04569021084029216, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01336925412929519, 'bootstrap': True, 'oob_score': True, 'max_samples': None, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0027992950162227448}. Best is trial 42 with value: 0.7879113107751802.
# [I 2024-10-22 04:44:14,973] Trial 44 finished with value: 0.7911868887363253 and parameters: {'n_estimators': 185, 'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.06150295503407646, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.007361758079464623, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': 'balanced', 'ccp_alpha': 0.006445242602594307}. Best is trial 44 with value: 0.7911868887363253.
# [I 2024-10-22 04:44:18,590] Trial 45 finished with value: 0.7789428508273902 and parameters: {'n_estimators': 162, 'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.017558215941592195, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01990708076057383, 'bootstrap': False, 'class_weight': 'balanced', 'ccp_alpha': 0.01912254850405644}. Best is trial 44 with value: 0.7911868887363253.
# [I 2024-10-22 04:44:27,032] Trial 46 finished with value: 0.7721102287054896 and parameters: {'n_estimators': 151, 'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.05998220736078602, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.005047750796291635, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.006310919348234623}. Best is trial 44 with value: 0.7911868887363253.
# [I 2024-10-22 04:44:29,214] Trial 47 finished with value: 0.7647667325200023 and parameters: {'n_estimators': 181, 'criterion': 'entropy', 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.07827157588196065, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.03119295045050856, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': 'balanced', 'ccp_alpha': 0.00991277106541262}. Best is trial 44 with value: 0.7911868887363253.
# [I 2024-10-22 04:44:33,227] Trial 48 finished with value: 0.7837917473765973 and parameters: {'n_estimators': 286, 'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.048667057261877866, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.014367865691639909, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': 'balanced', 'ccp_alpha': 0.0025077949387241677}. Best is trial 44 with value: 0.7911868887363253.
# [I 2024-10-22 04:44:36,025] Trial 49 finished with value: 0.7774018965485185 and parameters: {'n_estimators': 228, 'criterion': 'entropy', 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.0633829560991035, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.02261592637909987, 'bootstrap': True, 'oob_score': False, 'max_samples': 1.0, 'class_weight': 'balanced', 'ccp_alpha': 0.015502139806424944}. Best is trial 44 with value: 0.7911868887363253.
# [I 2024-10-22 04:44:39,353] Trial 50 finished with value: 0.7915756736080077 and parameters: {'n_estimators': 184, 'criterion': 'entropy', 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.07343146260057545, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0001583385020952925, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.006136960791266121}. Best is trial 50 with value: 0.7915756736080077.
# [I 2024-10-22 04:44:42,745] Trial 51 finished with value: 0.7882593992495612 and parameters: {'n_estimators': 189, 'criterion': 'entropy', 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.07428553505334141, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0002489247472225465, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.008202323951187312}. Best is trial 50 with value: 0.7915756736080077.
# [I 2024-10-22 04:44:47,213] Trial 52 finished with value: 0.7893149921809206 and parameters: {'n_estimators': 186, 'criterion': 'entropy', 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.07616147225549143, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.005095880021686386, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0
 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.003287951591153894}. Best is trial 66 with value: 0.8071303393363389.
# [I 2024-10-22 04:47:40,684] Trial 93 finished with value: 0.8038597881721533 and parameters: {'n_estimators': 178, 'criterion': 'entropy', 'max_depth': 23, 'min_samples_split': 9, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.020974208173344916, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.001497783885943349, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.003493986057827432}. Best is trial 66 with value: 0.8071303393363389.
# [I 2024-10-22 04:47:43,627] Trial 94 finished with value: 0.7963293708860314 and parameters: {'n_estimators': 177, 'criterion': 'entropy', 'max_depth': 23, 'min_samples_split': 10, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.006372022986604229, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.0060885590621772975, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0037842732137440844}. Best is trial 66 with value: 0.8071303393363389.
# [I 2024-10-22 04:47:47,320] Trial 95 finished with value: 0.8101844972204566 and parameters: {'n_estimators': 173, 'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.021718504190443414, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.00020050960333953174, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0010040314628222235}. Best is trial 95 with value: 0.8101844972204566.
# [I 2024-10-22 04:47:54,166] Trial 96 finished with value: 0.752648536685633 and parameters: {'n_estimators': 179, 'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 9, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.02101379231657013, 'max_features': None, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.007878615861521786, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.005450774062337833}. Best is trial 95 with value: 0.8101844972204566.
# [I 2024-10-22 04:47:57,537] Trial 97 finished with value: 0.7950182376325301 and parameters: {'n_estimators': 203, 'criterion': 'entropy', 'max_depth': 24, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.02785571265083422, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.005835615707599173, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0009170517425165723}. Best is trial 95 with value: 0.8101844972204566.
# [I 2024-10-22 04:48:00,997] Trial 98 finished with value: 0.804428160529728 and parameters: {'n_estimators': 159, 'criterion': 'entropy', 'max_depth': 23, 'min_samples_split': 9, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.012713965416752678, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.00022566991186442962, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.003816439685986332}. Best is trial 95 with value: 0.8101844972204566.
# [I 2024-10-22 04:48:04,889] Trial 99 finished with value: 0.7945071914183623 and parameters: {'n_estimators': 173, 'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 9, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.01360511646453736, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.00018067260447103447, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.007089953722439653}. Best is trial 95 with value: 0.8101844972204566.

# %%
# Print the best hyperparameters and best ROC-AUC score
print("Best hyperparameters:", study_rf.best_params)
print("Best ROC-AUC score:", study_rf.best_value)
# Out:
# Best hyperparameters: {'n_estimators': 173, 'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.021718504190443414, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.00020050960333953174, 'bootstrap': False, 'class_weight': 'balanced_subsample', 'ccp_alpha': 0.0010040314628222235}
# Best ROC-AUC score: 0.8101844972204566

# %%
# Specify the path where you want to save the JSON file
config_file_path = Path("random_forest_apsiii_best_configs.json")

# Load the saved configuration (if it exists)
if config_file_path.exists():
    with open(config_file_path, "r") as config_file:
        saved_configs = json.load(config_file)

    # Compare the new best value with the saved one
    if study_rf.best_value > saved_configs["best_value"]:
        print("New best value found. Replacing saved configuration.")
        saved_configs["best_params"] = study_rf.best_params
        saved_configs["best_value"] = study_rf.best_value

        # Update the saved configuration file
        with open(config_file_path, "w") as config_file:
            json.dump(saved_configs, config_file)
else:
    # If no saved configuration exists, create a new one
    saved_configs = {
        "best_params": study_rf.best_params,
        "best_value": study_rf.best_value
    }

    with open(config_file_path, "w") as config_file:
        json.dump(saved_configs, config_file)

# %% [markdown]
# ## XGBoost Optuna Optimization

# %%
# Define the objective function for Optuna hyperparameter tuning
def objective_xgboost(trial: optuna.Trial):
    try:
        # Split the data into training and validation sets
        x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(
            X_balanced, y_balanced, test_size=0.2, random_state=42, stratify=y_balanced
        )

        # Initialize StandardScaler
        scaler = StandardScaler()

        # Fit the scaler on the training data and transform both the training and validation sets
        x_train_split = scaler.fit_transform(x_train_split)
        x_valid_split = scaler.transform(x_valid_split)

        # Suggest hyperparameters for XGBoost
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3)
        max_depth = trial.suggest_int('max_depth', 3, 10)
        min_child_weight = trial.suggest_float('min_child_weight', 1, 10)
        subsample = trial.suggest_float('subsample', 0.5, 1.0)
        colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
        reg_alpha = trial.suggest_float('reg_alpha', 0.0, 10.0)
        reg_lambda = trial.suggest_float('reg_lambda', 0.0, 10.0)
        scale_pos_weight = trial.suggest_float('scale_pos_weight', 1.0, 5.0)
        n_estimators = trial.suggest_int('n_estimators', 100, 500)
        gamma = trial.suggest_float('gamma', 0.0, 5.0)
        max_delta_step = trial.suggest_float('max_delta_step', 0.0, 10.0)

        # Train the model with the sampled hyperparameters
        _, results_xgb = train_xgboost_model(
            X_train=x_train_split,
            y_train=y_train_split,
            X_test=x_valid_split,
            objective='binary:logistic',
            booster='gbtree',
            learning_rate=learning_rate,
            max_depth=max_depth,
            min_child_weight=min_child_weight,
            subsample=subsample,
            colsample_bytree=colsample_bytree,
            reg_alpha=reg_alpha,
            reg_lambda=reg_lambda,
            scale_pos_weight=scale_pos_weight,
            n_estimators=n_estimators,
            gamma=gamma,
            max_delta_step=max_delta_step,
            random_state=42,  # Fixed random state for reproducibility
            verbosity=0
        )

        # Calculate the ROC-AUC score on validation data
        roc_auc = roc_auc_score(y_valid_split, results_xgb['y_pred_prob'])

        # Maximize ROC-AUC
        return roc_auc

    except Exception as e:
        # Print the error for debugging purposes (optional)
        print(f"Trial failed with error: {e}")
        
        # Return 0.0 ROC-AUC to indicate failure
        return 0.0

# %%
# Create an Optuna study with SQLite storage and TPE pruner
study_name = "Optuna_hyperparameter_optimization"
storage_name = "sqlite:///{}.db".format(study_name)

study_xgb = optuna.create_study(
    study_name="Case 12: XGBoost_APSIII",
    direction="maximize",  # Maximize ROC-AUC
    storage=storage_name,
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5),  
)

# Perform a trial with default values first
default_params = {
    'learning_rate': 0.3,
    'max_depth': 6,
    'min_child_weight': 1,
    'subsample': 1,
    'colsample_bytree': 1,
    'reg_alpha': 0.0,
    'reg_lambda': 1.0,
    'scale_pos_weight': 1.0,
    'n_estimators': 100,
    'gamma': 0.0,
    'max_delta_step': 0.0
}
study_xgb.enqueue_trial(default_params)

# Define the number of trials (hyperparameter combinations) to search
num_trials = 100

# Perform hyperparameter optimization
study_xgb.optimize(objective_xgboost, n_trials=num_trials, n_jobs=1)
# Out:
# [I 2024-10-22 04:48:05,012] A new study created in RDB with name: Case 12: XGBoost_APSIII
# [I 2024-10-22 04:48:06,192] Trial 0 finished with value: 0.841355217574233 and parameters: {'learning_rate': 0.3, 'max_depth': 6, 'min_child_weight': 1.0, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'scale_pos_weight': 1.0, 'n_estimators': 100, 'gamma': 0.0, 'max_delta_step': 0.0}. Best is trial 0 with value: 0.841355217574233.
# [I 2024-10-22 04:48:07,693] Trial 1 finished with value: 0.8473209238013327 and parameters: {'learning_rate': 0.17018722655544372, 'max_depth': 6, 'min_child_weight': 8.744634963483751, 'subsample': 0.628190108318754, 'colsample_bytree': 0.9205455596402545, 'reg_alpha': 4.418715018789152, 'reg_lambda': 9.327579114175421, 'scale_pos_weight': 2.729630879894991, 'n_estimators': 132, 'gamma': 4.227482500136408, 'max_delta_step': 1.3878178522952522}. Best is trial 1 with value: 0.8473209238013327.
# [I 2024-10-22 04:48:09,353] Trial 2 finished with value: 0.8443583844563174 and parameters: {'learning_rate': 0.28332802404779417, 'max_depth': 7, 'min_child_weight': 4.27672206790624, 'subsample': 0.8954327749844297, 'colsample_bytree': 0.6490772088534926, 'reg_alpha': 6.121657050424414, 'reg_lambda': 5.514543802983736, 'scale_pos_weight': 4.406863374734179, 'n_estimators': 175, 'gamma': 2.2255408750468404, 'max_delta_step': 9.6253145534687}. Best is trial 1 with value: 0.8473209238013327.
# [I 2024-10-22 04:48:13,079] Trial 3 finished with value: 0.8451643590455147 and parameters: {'learning_rate': 0.15821921743263576, 'max_depth': 6, 'min_child_weight': 4.821239683823496, 'subsample': 0.598009128497291, 'colsample_bytree': 0.6486087545994299, 'reg_alpha': 7.620475870757897, 'reg_lambda': 0.367062777858711, 'scale_pos_weight': 1.3229651941414402, 'n_estimators': 429, 'gamma': 0.7850467913958753, 'max_delta_step': 9.416237281082806}. Best is trial 1 with value: 0.8473209238013327.
# [I 2024-10-22 04:48:18,196] Trial 4 finished with value: 0.8234132708816932 and parameters: {'learning_rate': 0.17278936204616574, 'max_depth': 9, 'min_child_weight': 1.5478522083654864, 'subsample': 0.5446218637194229, 'colsample_bytree': 0.5041278268543024, 'reg_alpha': 0.18625469471605371, 'reg_lambda': 0.7538955877947473, 'scale_pos_weight': 3.5646955836468055, 'n_estimators': 390, 'gamma': 0.23301058566170874, 'max_delta_step': 0.31394956491660464}. Best is trial 1 with value: 0.8473209238013327.
# [I 2024-10-22 04:56:44,589] Trial 97 finished with value: 0.8456733738828287 and parameters: {'learning_rate': 0.021525587404123678, 'max_depth': 5, 'min_child_weight': 5.313935924668906, 'subsample': 0.5672362962387556, 'colsample_bytree': 0.6183740249915242, 'reg_alpha': 1.479204713172109, 'reg_lambda': 0.01795238716740788, 'scale_pos_weight': 3.7683664271934125, 'n_estimators': 382, 'gamma': 0.975246925415296, 'max_delta_step': 4.750062924838511}. Best is trial 76 with value: 0.8508937369552898.
# [I 2024-10-22 04:56:50,672] Trial 98 finished with value: 0.8491607659185921 and parameters: {'learning_rate': 0.02988379008363097, 'max_depth': 6, 'min_child_weight': 4.751920682305, 'subsample': 0.579266103004318, 'colsample_bytree': 0.5911624871063837, 'reg_alpha': 2.01310452005746, 'reg_lambda': 4.646188517400804, 'scale_pos_weight': 3.2047593710553235, 'n_estimators': 368, 'gamma': 1.2384593305455078, 'max_delta_step': 9.209994692309582}. Best is trial 76 with value: 0.8508937369552898.
# [I 2024-10-22 04:56:56,534] Trial 99 finished with value: 0.8492085204897063 and parameters: {'learning_rate': 0.039794856047651234, 'max_depth': 5, 'min_child_weight': 6.277697104793177, 'subsample': 0.5990612129232488, 'colsample_bytree': 0.7834030072173825, 'reg_alpha': 3.814410145976381, 'reg_lambda': 2.1701552366950088, 'scale_pos_weight': 3.87950396503774, 'n_estimators': 415, 'gamma': 0.692444711855873, 'max_delta_step': 6.790491866109118}. Best is trial 76 with value: 0.8508937369552898.

# %%
# Print the best hyperparameters and best ROC-AUC score
print("Best hyperparameters:", study_xgb.best_params)
print("Best ROC-AUC score:", study_xgb.best_value)
# Out:
# Best hyperparameters: {'learning_rate': 0.03437114678262486, 'max_depth': 6, 'min_child_weight': 9.588464219127449, 'subsample': 0.5465076961620297, 'colsample_bytree': 0.6003002614899823, 'reg_alpha': 8.579602514350436, 'reg_lambda': 1.1803238056562555, 'scale_pos_weight': 3.8307394260658176, 'n_estimators': 460, 'gamma': 1.8349690471934739, 'max_delta_step': 9.944174595339588}
# Best ROC-AUC score: 0.8508937369552898

# %%
# Save the best configurations to a JSON file
config_file_path = Path("xgboost_apsiii_best_configs.json")

# Load the saved configuration (if it exists)
if config_file_path.exists():
    with open(config_file_path, "r") as config_file:
        saved_configs = json.load(config_file)

    # Compare the new best value with the saved one
    if study_xgb.best_value > saved_configs["best_value"]:
        print("New best value found. Replacing saved configuration.")
        saved_configs["best_params"] = study_xgb.best_params
        saved_configs["best_value"] = study_xgb.best_value

        # Update the saved configuration file
        with open(config_file_path, "w") as config_file:
            json.dump(saved_configs, config_file)
else:
    # If no saved configuration exists, create a new one
    saved_configs = {
        "best_params": study_xgb.best_params,
        "best_value": study_xgb.best_value
    }

    with open(config_file_path, "w") as config_file:
        json.dump(saved_configs, config_file)

# %% [markdown]
# # End
